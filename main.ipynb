# %% [markdown]
# # 1. Formulação do problema
#
# ### Variáveis de Decisão:
# - **ti**: Tempo de pouso do avião i (variável contínua);
#
#
# - **xij**: Variável binária que vale 1 se o avião i pousar antes do avião j, 0 caso contrário;
#
#
# - **ei**: Adiantamento do tempo ideal de pouso para o avião i (ei ≥ 0);
#
#
# - **di**: Atraso do tempo ideal de pouso para o avião i (di ≥ 0).
#
# ### Parâmetros:
# - **Ri**: Tempo de sua detecção pelo radar;
#
#
# - **Ei**: Tempo inicial de pouso;
#
#
# - **Ti**: Tempo ideal para o pouso;
#
#
# - **Li**: Tempo final que o avião i pode pousar;
#
#
# ### Função Objetivo:
# Minimizar a penalidade total de pousos fora do tempo ideal:
#
#    ### **Minimizar ∑ (gi * ei + hi * di)**
#
# Onde:
# - **gi** e **hi** são as penalidades por pousar antes ou depois do tempo ideal, respectivamente.
#
# ### Restrições:
#
# #### **Restrições de Separação:**
# O intervalo entre os pousos deve ser suficiente para garantir segurança e garantir uma sequência válida de aterrissagens:
#
# - **tj ≥ ti + sij − M(1 − xij), ∀i,j, i≠j**
#
#     Se **xij = 1**, então **tj ≥ ti + sij**, garantindo a separação mínima entre os pousos.
#
#
#     Se **xij = 0**, a restrição é relaxada devido ao termo **M(1 − xij)**.
#
# - **ti ≥ tj + sji − Mxij, ∀i,j, i≠j**
#             Similar à restrição anterior, mas garantindo que a relação entre **ti** e **tj** seja consistente dependendo do valor de    **xij**.
#
# #### **Restrições de Sequenciamento:**
# Garante que para cada par de aviões **(i, j)**, um deve pousar antes do outro, evitando ciclos:
#
# - **xij + xji = 1, ∀i,j, i≠j**
#         Isso assegura que se o avião **i** pousar antes de **j**, então **xij = 1** e **xji = 0**, caso contrário, **xij = 0** e **xji = 1**.
#
# #### **Cálculo de Adiantamento e Atraso:**
#
# - **ei ≥ Ti − ti ∀i**;
#
#
# - **di ≥ ti − Ti ∀i**;
#
#
# - **ei ≤ Ti − Ei ∀i**;
#
#
# - **di ≤ Li − Ti ∀i**.

# %% [markdown]
# # 2. Resolvendo usando o solver CBC

# %%
# !pip install pulp
# !sudo apt-get install glpk-utils

# %%
import time
from pulp import LpProblem, LpVariable, LpMinimize, lpSum, LpBinary, PULP_CBC_CMD, value

def ler_dados_instancia(caminho_arquivo):
    with open(caminho_arquivo, 'r') as arquivo:
        linha_inicial = arquivo.readline().strip().split()
        qtdeDeAvioes = int(linha_inicial[0])

        tempos = []
        separacoes = []
        penalidades = []

        for _ in range(qtdeDeAvioes):
            linha_tempos = arquivo.readline().strip().split()
            while len(linha_tempos) < 6:
                linha_tempos.extend(arquivo.readline().strip().split())
            ri, ei, ti, li, gi, hi = map(float, linha_tempos[:6])
            tempos.append((ri, ei, ti, li, gi, hi))
            penalidades.append((gi, hi))

            linha_separacao = []
            while len(linha_separacao) < qtdeDeAvioes:
                linha_separacao.extend(arquivo.readline().strip().split())
            separacoes.append(list(map(float, linha_separacao[:qtdeDeAvioes])))

        return qtdeDeAvioes, tempos, separacoes, penalidades


def resolver_modelo_glpk(qtdeDeAvioes, tempos, separacoes, penalidades):
    modelo = LpProblem("SequenciamentoPousos", LpMinimize)

    # Variáveis de decisão
    t = [LpVariable(f"t_{i}", lowBound=tempos[i][1], upBound=tempos[i][3], cat='Continuous') for i in range(qtdeDeAvioes)]
    e = [LpVariable(f"e_{i}", lowBound=0, cat='Continuous') for i in range(qtdeDeAvioes)]
    d = [LpVariable(f"d_{i}", lowBound=0, cat='Continuous') for i in range(qtdeDeAvioes)]
    x = [[LpVariable(f"x_{i}_{j}", cat=LpBinary) if i != j else None for j in range(qtdeDeAvioes)] for i in range(qtdeDeAvioes)]

    # Função objetivo
    modelo += lpSum(penalidades[i][0] * e[i] + penalidades[i][1] * d[i] for i in range(qtdeDeAvioes)), "PenalidadeTotal"

    # Constante grande M
    M = max(tempos[i][3] for i in range(qtdeDeAvioes)) + max(max(separacoes[i]) for i in range(qtdeDeAvioes))

    # Restrições de separação e sequenciamento
    for i in range(qtdeDeAvioes):
        for j in range(qtdeDeAvioes):
            if i != j:
                modelo += t[j] >= t[i] + separacoes[i][j] - M * (1 - x[i][j]), f"Separacao_{i}_{j}_A"
                modelo += t[i] >= t[j] + separacoes[j][i] - M * x[i][j], f"Separacao_{j}_{i}_B"
                modelo += x[i][j] + x[j][i] == 1, f"Sequencia_{i}_{j}"

    # Cálculo de adiantamento e atraso
    for i in range(qtdeDeAvioes):
        modelo += e[i] >= tempos[i][2] - t[i], f"Adiantamento_{i}"
        modelo += d[i] >= t[i] - tempos[i][2], f"Atraso_{i}"
        modelo += e[i] <= tempos[i][2] - tempos[i][1], f"LimiteAdiantamento_{i}"
        modelo += d[i] <= tempos[i][3] - tempos[i][2], f"LimiteAtraso_{i}"

    # Resolver o modelo com tempo limite
    inicio_tempo = time.time()
    resultado = modelo.solve(PULP_CBC_CMD(msg=True, timeLimit=640))
    tempo_execucao = time.time() - inicio_tempo

    if modelo.status == 1:  # Solução ótima encontrada
        tempos_pouso = [value(t[i]) for i in range(qtdeDeAvioes)]
        valor_otimo = value(modelo.objective)
        print(f"Valor ótimo da solução: {valor_otimo}")
        print(f"Tempos de pouso: {', '.join(map(str, tempos_pouso))}")
        print(f"Tempo de execução do Solver: {tempo_execucao:.2f} segundos")
    else:  # Solução aproximada
        tempos_pouso = [value(t[i]) for i in range(qtdeDeAvioes) if t[i].varValue is not None]
        valor_aproximado = value(modelo.objective) if value(modelo.objective) is not None else float('inf')
        print("Solução aproximada encontrada (não ótima dentro do tempo limite)")
        print(f"Penalidade aproximada: {valor_aproximado}")
        print(f"Tempos de pouso aproximados: {', '.join(map(str, tempos_pouso))}")
        print(f"Tempo de execução do Solver: {tempo_execucao:.2f} segundos")


def executarInstancia():
    for i in range(1, 9):
        caminho_arquivo = f"problema_do_aviao/instances/0{i}.dat"
        qtdeDeAvioes, tempos, separacoes, penalidades = ler_dados_instancia(caminho_arquivo)
        resolver_modelo_glpk(qtdeDeAvioes, tempos, separacoes, penalidades)


executarInstancia()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1cd4fa8d0fe743a2b356e7654f345877-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/1cd4fa8d0fe743a2b356e7654f345877-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 315 COLUMNS
# At line 1296 RHS
# At line 1607 BOUNDS
# At line 1718 ENDATA
# Problem MODEL has 310 rows, 120 columns and 780 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0004I processed model has 110 rows, 75 columns (45 integer (45 of which binary)) and 326 elements
# Cbc0038I Initial state - 23 integers unsatisfied sum - 1.42588
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 8430 iterations 48
# Cbc0038I Solution found of 8430
# Cbc0038I Relaxing continuous gives 8430
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 11 continuous
# Cbc0038I Full problem 110 rows 75 columns, reduced to 65 rows 39 columns
# Cbc0038I Mini branch and bound improved solution from 8430 to 1570 (0.03 seconds)
# Cbc0038I Round again with cutoff of 1413
# Cbc0038I Pass   2: suminf.    0.85739 (21) obj. 1413 iterations 32
# Cbc0038I Pass   3: suminf.    0.00000 (0) obj. 1413 iterations 45
# Cbc0038I Solution found of 1413
# Cbc0038I Relaxing continuous gives 1180
# Cbc0038I Before mini branch and bound, 22 integers at bound fixed and 10 continuous
# Cbc0038I Full problem 110 rows 75 columns, reduced to 45 rows 31 columns
# Cbc0038I Mini branch and bound improved solution from 1180 to 740 (0.03 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 700
# Cbc0038I Round again with cutoff of 560
# Cbc0038I Pass   4: suminf.    1.17434 (22) obj. 560 iterations 4
# Cbc0038I Pass   5: suminf.    0.37488 (12) obj. 560 iterations 20
# Cbc0038I Pass   6: suminf.    0.00002 (1) obj. 560 iterations 36
# Cbc0038I Pass   7: suminf.    0.00002 (1) obj. 560 iterations 0
# Cbc0038I Pass   8: suminf.    0.44999 (9) obj. 560 iterations 20
# Cbc0038I Pass   9: suminf.    0.37482 (8) obj. 560 iterations 2
# Cbc0038I Pass  10: suminf.    0.00012 (3) obj. 560 iterations 28
# Cbc0038I Pass  11: suminf.    0.00012 (3) obj. 560 iterations 0
# Cbc0038I Pass  12: suminf.    0.58152 (10) obj. 560 iterations 15
# Cbc0038I Pass  13: suminf.    0.05680 (7) obj. 560 iterations 6
# Cbc0038I Pass  14: suminf.    0.00152 (7) obj. 560 iterations 6
# Cbc0038I Pass  15: suminf.    0.00152 (7) obj. 560 iterations 0
# Cbc0038I Pass  16: suminf.    0.79210 (15) obj. 560 iterations 19
# Cbc0038I Pass  17: suminf.    0.00039 (5) obj. 560 iterations 23
# Cbc0038I Pass  18: suminf.    0.00039 (5) obj. 560 iterations 0
# Cbc0038I Pass  19: suminf.    0.68431 (13) obj. 560 iterations 20
# Cbc0038I Pass  20: suminf.    0.18182 (11) obj. 560 iterations 6
# Cbc0038I Pass  21: suminf.    0.00029 (6) obj. 560 iterations 16
# Cbc0038I Pass  22: suminf.    0.00029 (6) obj. 560 iterations 0
# Cbc0038I Pass  23: suminf.    1.12318 (21) obj. 560 iterations 28
# Cbc0038I Pass  24: suminf.    0.86493 (21) obj. 560 iterations 3
# Cbc0038I Pass  25: suminf.    0.00096 (6) obj. 560 iterations 32
# Cbc0038I Pass  26: suminf.    0.00096 (6) obj. 560 iterations 0
# Cbc0038I Pass  27: suminf.    0.65270 (14) obj. 560 iterations 25
# Cbc0038I Pass  28: suminf.    0.48353 (13) obj. 560 iterations 1
# Cbc0038I Pass  29: suminf.    0.00061 (4) obj. 560 iterations 22
# Cbc0038I Pass  30: suminf.    0.00061 (4) obj. 560 iterations 0
# Cbc0038I Pass  31: suminf.    0.73310 (11) obj. 560 iterations 16
# Cbc0038I Pass  32: suminf.    0.16024 (9) obj. 560 iterations 4
# Cbc0038I Pass  33: suminf.    0.00086 (6) obj. 560 iterations 9
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 3 continuous
# Cbc0038I Full problem 110 rows 75 columns, reduced to 92 rows 62 columns
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 700 - took 0.05 seconds
# Cbc0012I Integer solution of 700 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 110 rows 75 columns, reduced to 88 rows 53 columns
# Cbc0031I 19 added rows had average density of 11.263158
# Cbc0013I At root node, 19 cuts changed objective from 0 to 419.60766 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 227 row cuts average 3.7 elements, 25 column cuts (25 active)  in 0.016 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 251 row cuts average 16.4 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 11 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 44 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 700 best solution, best possible 419.60768 (0.16 seconds)
# Cbc0001I Search completed - best objective 700, took 1130 iterations and 8 nodes (0.19 seconds)
# Cbc0032I Strong branching done 36 times (357 iterations), fathomed 3 nodes and fixed 2 variables
# Cbc0035I Maximum depth 3, 1 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 419.608
# Probing was tried 151 times and created 295 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Gomory was tried 150 times and created 319 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# TwoMirCuts was tried 150 times and created 60 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 50 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                700.00000000
# Enumerated nodes:               8
# Total iterations:               1130
# Time (CPU seconds):             0.19
# Time (Wallclock seconds):       0.20
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.20   (Wallclock seconds):       0.20
#
# Valor ótimo da solução: 699.999999999892
# Tempos de pouso: 165.0, 258.0, 98.0, 106.0, 118.0, 126.0, 134.0, 142.0, 150.0, 180.0
# Tempo de execução do Solver: 0.22 segundos
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2c4e458980b74718b093923571b0022e-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/2c4e458980b74718b093923571b0022e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 695 COLUMNS
# At line 2916 RHS
# At line 3607 BOUNDS
# At line 3848 ENDATA
# Problem MODEL has 690 rows, 255 columns and 1770 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0004I processed model has 240 rows, 150 columns (105 integer (105 of which binary)) and 725 elements
# Cbc0038I Initial state - 31 integers unsatisfied sum - 2.23897
# Cbc0038I Pass   1: suminf.    0.00012 (1) obj. 12310 iterations 60
# Cbc0038I Pass   2: suminf.    0.00012 (1) obj. 12310 iterations 0
# Cbc0038I Pass   3: suminf.    0.01080 (24) obj. 48714.9 iterations 50
# Cbc0038I Pass   4: suminf.    0.01080 (24) obj. 48714.9 iterations 0
# Cbc0038I Pass   5: suminf.    0.01080 (24) obj. 48714.9 iterations 0
# Cbc0038I Pass   6: suminf.    0.01647 (43) obj. 50297.7 iterations 52
# Cbc0038I Pass   7: suminf.    0.01647 (43) obj. 50297.7 iterations 0
# Cbc0038I Pass   8: suminf.    0.01647 (43) obj. 50297.7 iterations 0
# Cbc0038I Pass   9: suminf.    0.01974 (48) obj. 51064.6 iterations 35
# Cbc0038I Pass  10: suminf.    0.01974 (48) obj. 51064.6 iterations 0
# Cbc0038I Pass  11: suminf.    0.01974 (48) obj. 51064.6 iterations 0
# Cbc0038I Pass  12: suminf.    0.01885 (47) obj. 50074.8 iterations 24
# Cbc0038I Pass  13: suminf.    0.01885 (47) obj. 50074.8 iterations 0
# Cbc0038I Pass  14: suminf.    0.01885 (47) obj. 50074.8 iterations 0
# Cbc0038I Pass  15: suminf.    0.01997 (48) obj. 49466.6 iterations 30
# Cbc0038I Pass  16: suminf.    0.01997 (48) obj. 49466.6 iterations 0
# Cbc0038I Pass  17: suminf.    0.01997 (48) obj. 49466.6 iterations 0
# Cbc0038I Pass  18: suminf.    0.02119 (50) obj. 51304 iterations 38
# Cbc0038I Pass  19: suminf.    0.02119 (50) obj. 51304 iterations 0
# Cbc0038I Pass  20: suminf.    0.02119 (50) obj. 51304 iterations 0
# Cbc0038I Pass  21: suminf.    0.02051 (49) obj. 53480 iterations 36
# Cbc0038I Pass  22: suminf.    0.02051 (49) obj. 53480 iterations 0
# Cbc0038I Pass  23: suminf.    0.02051 (49) obj. 53480 iterations 0
# Cbc0038I Pass  24: suminf.    0.02242 (53) obj. 50280 iterations 35
# Cbc0038I Pass  25: suminf.    0.02242 (53) obj. 50280 iterations 0
# Cbc0038I Pass  26: suminf.    0.02242 (53) obj. 50280 iterations 0
# Cbc0038I Pass  27: suminf.    0.02172 (50) obj. 50250 iterations 20
# Cbc0038I Pass  28: suminf.    0.02172 (50) obj. 50250 iterations 0
# Cbc0038I Pass  29: suminf.    0.02172 (50) obj. 50250 iterations 0
# Cbc0038I Pass  30: suminf.    0.02222 (54) obj. 54274.7 iterations 47
# Cbc0038I Rounding solution of 12310 is better than previous of 1e+50
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 6 continuous
# Cbc0038I Full problem 240 rows 150 columns, reduced to 235 rows 140 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of 11079
# Cbc0038I Pass  30: suminf.    0.00043 (4) obj. 11079 iterations 5
# Cbc0038I Pass  31: suminf.    0.00043 (4) obj. 11079 iterations 0
# Cbc0038I Pass  32: suminf.    1.29573 (33) obj. 11079 iterations 62
# Cbc0038I Pass  33: suminf.    1.14555 (32) obj. 11079 iterations 2
# Cbc0038I Pass  34: suminf.    0.00728 (15) obj. 11079 iterations 48
# Cbc0038I Pass  35: suminf.    0.00594 (14) obj. 11079 iterations 4
# Cbc0038I Pass  36: suminf.    0.00594 (14) obj. 11079 iterations 0
# Cbc0038I Pass  37: suminf.    1.52874 (33) obj. 11079 iterations 57
# Cbc0038I Pass  38: suminf.    0.57050 (31) obj. 11079 iterations 12
# Cbc0038I Pass  39: suminf.    0.00219 (13) obj. 11079 iterations 70
# Cbc0038I Pass  40: suminf.    0.00219 (13) obj. 11079 iterations 0
# Cbc0038I Pass  41: suminf.    0.91668 (28) obj. 11079 iterations 48
# Cbc0038I Pass  42: suminf.    0.00472 (19) obj. 11079 iterations 36
# Cbc0038I Pass  43: suminf.    0.00310 (16) obj. 11079 iterations 2
# Cbc0038I Pass  44: suminf.    0.00310 (16) obj. 11079 iterations 0
# Cbc0038I Pass  45: suminf.    0.43576 (36) obj. 11079 iterations 58
# Cbc0038I Pass  46: suminf.    0.00421 (15) obj. 11079 iterations 46
# Cbc0038I Pass  47: suminf.    0.00310 (14) obj. 11079 iterations 1
# Cbc0038I Pass  48: suminf.    0.00310 (14) obj. 11079 iterations 0
# Cbc0038I Pass  49: suminf.    0.01282 (23) obj. 11079 iterations 56
# Cbc0038I Pass  50: suminf.    0.00457 (18) obj. 11079 iterations 10
# Cbc0038I Pass  51: suminf.    0.00457 (18) obj. 11079 iterations 0
# Cbc0038I Pass  52: suminf.    0.01861 (27) obj. 11079 iterations 60
# Cbc0038I Pass  53: suminf.    0.00406 (16) obj. 11079 iterations 28
# Cbc0038I Pass  54: suminf.    0.00406 (16) obj. 11079 iterations 0
# Cbc0038I Pass  55: suminf.    0.09052 (26) obj. 11079 iterations 54
# Cbc0038I Pass  56: suminf.    0.00624 (18) obj. 11079 iterations 21
# Cbc0038I Pass  57: suminf.    0.00624 (18) obj. 11079 iterations 0
# Cbc0038I Pass  58: suminf.    1.05944 (41) obj. 11079 iterations 45
# Cbc0038I Pass  59: suminf.    0.57076 (41) obj. 11079 iterations 11
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 5 continuous
# Cbc0038I Full problem 240 rows 150 columns, reduced to 221 rows 129 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of 12310 - took 0.05 seconds
# Cbc0012I Integer solution of 11630 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0012I Integer solution of 10470 found by DiveCoefficient after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0038I Full problem 240 rows 150 columns, reduced to 166 rows 76 columns - 1 fixed gives 165, 75 - still too large
# Cbc0038I Full problem 240 rows 150 columns, reduced to 165 rows 75 columns - too large
# Cbc0012I Integer solution of 1790 found by DiveCoefficient after 1564 iterations and 0 nodes (0.37 seconds)
# Cbc0031I 29 added rows had average density of 15.862069
# Cbc0013I At root node, 29 cuts changed objective from 0 to 729.82277 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 411 row cuts average 4.8 elements, 0 column cuts (0 active)  in 0.098 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 495 row cuts average 31.2 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 32 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 94 row cuts average 7.7 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1790 best solution, best possible 729.82277 (0.37 seconds)
# Cbc0012I Integer solution of 1740 found by DiveCoefficient after 1631 iterations and 1 nodes (0.39 seconds)
# Cbc0012I Integer solution of 1510 found by DiveCoefficient after 3325 iterations and 42 nodes (0.64 seconds)
# Cbc0038I Full problem 240 rows 150 columns, reduced to 139 rows 49 columns - 1 fixed gives 138, 48 - still too large
# Cbc0038I Full problem 240 rows 150 columns, reduced to 138 rows 48 columns - too large
# Cbc0012I Integer solution of 1500 found by DiveCoefficient after 3368 iterations and 43 nodes (0.66 seconds)
# Cbc0012I Integer solution of 1480 found by DiveCoefficient after 4444 iterations and 69 nodes (0.78 seconds)
# Cbc0038I Full problem 240 rows 150 columns, reduced to 139 rows 49 columns - 1 fixed gives 138, 48 - still too large
# Cbc0038I Full problem 240 rows 150 columns, reduced to 137 rows 47 columns - too large
# Cbc0001I Search completed - best objective 1480, took 11592 iterations and 204 nodes (1.73 seconds)
# Cbc0032I Strong branching done 1120 times (11508 iterations), fathomed 46 nodes and fixed 102 variables
# Cbc0035I Maximum depth 11, 679 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 729.823
# Probing was tried 1132 times and created 2770 cuts of which 0 were active after adding rounds of cuts (0.213 seconds)
# Gomory was tried 1131 times and created 1819 cuts of which 0 were active after adding rounds of cuts (0.105 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 100 times and created 32 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# TwoMirCuts was tried 1131 times and created 255 cuts of which 0 were active after adding rounds of cuts (0.080 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1480.00000000
# Enumerated nodes:               204
# Total iterations:               11592
# Time (CPU seconds):             1.67
# Time (Wallclock seconds):       1.73
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.67   (Wallclock seconds):       1.73
#
# Valor ótimo da solução: 1480.0
# Tempos de pouso: 196.0, 250.0, 90.0, 98.0, 106.0, 130.0, 122.0, 114.0, 138.0, 151.0, 341.0, 313.0, 181.0, 171.0, 344.0
# Tempo de execução do Solver: 1.75 segundos
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f065b746ee3e41eda3eb157bc123d8eb-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/f065b746ee3e41eda3eb157bc123d8eb-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1225 COLUMNS
# At line 5186 RHS
# At line 6407 BOUNDS
# At line 6828 ENDATA
# Problem MODEL has 1220 rows, 440 columns and 3160 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 420 rows, 250 columns (190 integer (190 of which binary)) and 1260 elements
# Cbc0038I Initial state - 66 integers unsatisfied sum - 9.87703
# Cbc0038I Pass   1: suminf.    0.00131 (3) obj. 32250 iterations 119
# Cbc0038I Pass   2: suminf.    0.00131 (3) obj. 32250 iterations 0
# Cbc0038I Pass   3: suminf.    0.02935 (49) obj. 47709.5 iterations 79
# Cbc0038I Pass   4: suminf.    0.02138 (42) obj. 47709.5 iterations 7
# Cbc0038I Pass   5: suminf.    0.02138 (42) obj. 47709.5 iterations 0
# Cbc0038I Pass   6: suminf.    0.03177 (63) obj. 49209.1 iterations 43
# Cbc0038I Pass   7: suminf.    0.02961 (61) obj. 49209.1 iterations 2
# Cbc0038I Pass   8: suminf.    0.02961 (61) obj. 49209.1 iterations 0
# Cbc0038I Pass   9: suminf.    0.03102 (78) obj. 53199.5 iterations 52
# Cbc0038I Pass  10: suminf.    0.03102 (78) obj. 53199.5 iterations 0
# Cbc0038I Pass  11: suminf.    0.03102 (78) obj. 53199.5 iterations 0
# Cbc0038I Pass  12: suminf.    0.03535 (80) obj. 53129.8 iterations 47
# Cbc0038I Pass  13: suminf.    0.03429 (79) obj. 53129.8 iterations 1
# Cbc0038I Pass  14: suminf.    0.03429 (79) obj. 53129.8 iterations 0
# Cbc0038I Pass  15: suminf.    0.03670 (80) obj. 53009.6 iterations 44
# Cbc0038I Pass  16: suminf.    0.03556 (79) obj. 53009.6 iterations 1
# Cbc0038I Pass  17: suminf.    0.03556 (79) obj. 53009.6 iterations 0
# Cbc0038I Pass  18: suminf.    0.04041 (83) obj. 55144.8 iterations 58
# Cbc0038I Pass  19: suminf.    0.03605 (79) obj. 55144.8 iterations 4
# Cbc0038I Pass  20: suminf.    0.03605 (79) obj. 55144.8 iterations 0
# Cbc0038I Pass  21: suminf.    0.03442 (80) obj. 61776.5 iterations 43
# Cbc0038I Pass  22: suminf.    0.03442 (80) obj. 61776.5 iterations 0
# Cbc0038I Pass  23: suminf.    0.03442 (80) obj. 61776.5 iterations 0
# Cbc0038I Pass  24: suminf.    0.03402 (79) obj. 61379.5 iterations 37
# Cbc0038I Pass  25: suminf.    0.03300 (78) obj. 61379.5 iterations 1
# Cbc0038I Pass  26: suminf.    0.03300 (78) obj. 61379.5 iterations 0
# Cbc0038I Pass  27: suminf.    0.04015 (91) obj. 60208.3 iterations 49
# Cbc0038I Pass  28: suminf.    0.04015 (91) obj. 60208.3 iterations 0
# Cbc0038I Pass  29: suminf.    0.04015 (91) obj. 60208.3 iterations 0
# Cbc0038I Pass  30: suminf.    0.04818 (95) obj. 67884 iterations 70
# Cbc0038I Rounding solution of 32250 is better than previous of 1e+50
#
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 9 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 406 rows 228 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of 29025
# Cbc0038I Pass  30: suminf.    0.04572 (6) obj. 29025 iterations 9
# Cbc0038I Pass  31: suminf.    0.00144 (4) obj. 29025 iterations 7
# Cbc0038I Pass  32: suminf.    0.00144 (4) obj. 29025 iterations 0
# Cbc0038I Pass  33: suminf.    0.10175 (44) obj. 29025 iterations 81
# Cbc0038I Pass  34: suminf.    0.01379 (26) obj. 29025 iterations 37
# Cbc0038I Pass  35: suminf.    0.01120 (26) obj. 29025 iterations 15
# Cbc0038I Pass  36: suminf.    0.00782 (23) obj. 29025 iterations 5
# Cbc0038I Pass  37: suminf.    0.00782 (23) obj. 29025 iterations 0
# Cbc0038I Pass  38: suminf.    0.47059 (50) obj. 29025 iterations 110
# Cbc0038I Pass  39: suminf.    0.01509 (37) obj. 29025 iterations 57
# Cbc0038I Pass  40: suminf.    0.01304 (35) obj. 29025 iterations 3
# Cbc0038I Pass  41: suminf.    0.01304 (35) obj. 29025 iterations 0
# Cbc0038I Pass  42: suminf.    0.77278 (55) obj. 29025 iterations 108
# Cbc0038I Pass  43: suminf.    0.01596 (42) obj. 29025 iterations 59
# Cbc0038I Pass  44: suminf.    0.01329 (40) obj. 29025 iterations 7
# Cbc0038I Pass  45: suminf.    0.01329 (40) obj. 29025 iterations 0
# Cbc0038I Pass  46: suminf.    1.40525 (70) obj. 29025 iterations 145
# Cbc0038I Pass  47: suminf.    0.69988 (63) obj. 29025 iterations 20
# Cbc0038I Pass  48: suminf.    0.01872 (57) obj. 29025 iterations 78
# Cbc0038I Pass  49: suminf.    0.01872 (57) obj. 29025 iterations 0
# Cbc0038I Pass  50: suminf.    1.68722 (69) obj. 29025 iterations 124
# Cbc0038I Pass  51: suminf.    1.68722 (69) obj. 29025 iterations 0
# Cbc0038I Pass  52: suminf.    0.01385 (50) obj. 29025 iterations 146
# Cbc0038I Pass  53: suminf.    0.01385 (50) obj. 29025 iterations 0
# Cbc0038I Pass  54: suminf.    0.06179 (80) obj. 29025 iterations 114
# Cbc0038I Pass  55: suminf.    0.01795 (61) obj. 29025 iterations 63
# Cbc0038I Pass  56: suminf.    0.01664 (60) obj. 29025 iterations 1
# Cbc0038I Pass  57: suminf.    0.01664 (60) obj. 29025 iterations 0
# Cbc0038I Pass  58: suminf.    1.67177 (70) obj. 29025 iterations 157
# Cbc0038I Pass  59: suminf.    0.04015 (61) obj. 29025 iterations 52
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 23 integers at bound fixed and 7 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 389 rows 217 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.11 seconds)
# Cbc0038I After 0.11 seconds - Feasibility pump exiting with objective of 32250 - took 0.08 seconds
# Cbc0012I Integer solution of 31870 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0012I Integer solution of 28430 found by DiveCoefficient after 0 iterations and 0 nodes (0.13 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 296 rows 126 columns - 1 fixed gives 295, 125 - still too large
# Cbc0038I Full problem 420 rows 250 columns, reduced to 295 rows 125 columns - too large
# Cbc0012I Integer solution of 820 found by DiveCoefficient after 639 iterations and 0 nodes (0.31 seconds)
# Cbc0031I 64 added rows had average density of 6.640625
# Cbc0013I At root node, 64 cuts changed objective from 0 to 702.76571 in 58 passes
# Cbc0014I Cut generator 0 (Probing) - 200 row cuts average 3.1 elements, 0 column cuts (0 active)  in 0.044 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 231 row cuts average 19.9 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 60 row cuts average 2.9 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 153 row cuts average 5.2 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 820 best solution, best possible 702.76571 (0.32 seconds)
# Cbc0001I Search completed - best objective 820.0000000023283, took 1141 iterations and 14 nodes (0.46 seconds)
# Cbc0032I Strong branching done 88 times (1019 iterations), fathomed 5 nodes and fixed 6 variables
# Cbc0035I Maximum depth 3, 73 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 702.766
# Probing was tried 98 times and created 319 cuts of which 0 were active after adding rounds of cuts (0.052 seconds)
# Gomory was tried 98 times and created 266 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Knapsack was tried 58 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# Clique was tried 58 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 98 times and created 67 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# FlowCover was tried 58 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# TwoMirCuts was tried 98 times and created 179 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                820.00000000
# Enumerated nodes:               14
# Total iterations:               1141
# Time (CPU seconds):             0.45
# Time (Wallclock seconds):       0.47
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.45   (Wallclock seconds):       0.47
#
# Valor ótimo da solução: 820.0
# Tempos de pouso: 82.0, 197.0, 184.0, 117.0, 261.0, 101.0, 229.0, 109.0, 133.0, 141.0, 149.0, 125.0, 336.0, 316.0, 258.0, 409.0, 339.0, 287.0, 160.0, 169.0
# Tempo de execução do Solver: 0.51 segundos
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cc20a433e00745b683b6d33517631da9-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/cc20a433e00745b683b6d33517631da9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1225 COLUMNS
# At line 5186 RHS
# At line 6407 BOUNDS
# At line 6828 ENDATA
# Problem MODEL has 1220 rows, 440 columns and 3160 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0004I processed model has 420 rows, 250 columns (190 integer (190 of which binary)) and 1249 elements
# Cbc0038I Initial state - 81 integers unsatisfied sum - 8.84015
# Cbc0038I Pass   1: suminf.    0.00188 (5) obj. 41910 iterations 131
# Cbc0038I Pass   2: suminf.    0.00188 (5) obj. 41910 iterations 0
# Cbc0038I Pass   3: suminf.    0.03654 (54) obj. 67339.6 iterations 86
# Cbc0038I Pass   4: suminf.    0.02376 (43) obj. 67010 iterations 11
# Cbc0038I Pass   5: suminf.    0.02376 (43) obj. 67010 iterations 0
# Cbc0038I Pass   6: suminf.    0.03853 (62) obj. 66299.6 iterations 38
# Cbc0038I Pass   7: suminf.    0.02800 (53) obj. 66210 iterations 10
# Cbc0038I Pass   8: suminf.    0.02800 (53) obj. 66210 iterations 0
# Cbc0038I Pass   9: suminf.    0.04181 (64) obj. 69690 iterations 38
# Cbc0038I Pass  10: suminf.    0.03175 (55) obj. 69690 iterations 9
# Cbc0038I Pass  11: suminf.    0.03175 (55) obj. 69690 iterations 0
# Cbc0038I Pass  12: suminf.    0.03837 (59) obj. 77409.9 iterations 42
# Cbc0038I Pass  13: suminf.    0.03093 (53) obj. 77409.9 iterations 6
# Cbc0038I Pass  14: suminf.    0.03093 (53) obj. 77409.9 iterations 0
# Cbc0038I Pass  15: suminf.    0.04763 (65) obj. 77889.9 iterations 37
# Cbc0038I Pass  16: suminf.    0.03240 (53) obj. 77889.9 iterations 12
# Cbc0038I Pass  17: suminf.    0.03240 (53) obj. 77889.9 iterations 0
# Cbc0038I Pass  18: suminf.    0.05039 (68) obj. 99570.4 iterations 60
# Cbc0038I Pass  19: suminf.    0.02984 (52) obj. 97118.6 iterations 17
# Cbc0038I Pass  20: suminf.    0.02984 (52) obj. 97118.6 iterations 0
# Cbc0038I Pass  21: suminf.    0.03858 (64) obj. 96398.7 iterations 34
# Cbc0038I Pass  22: suminf.    0.02960 (57) obj. 96398.7 iterations 7
# Cbc0038I Pass  23: suminf.    0.02960 (57) obj. 96398.7 iterations 0
# Cbc0038I Pass  24: suminf.    0.03363 (64) obj. 96200 iterations 38
# Cbc0038I Pass  25: suminf.    0.03027 (61) obj. 96200 iterations 3
# Cbc0038I Pass  26: suminf.    0.03027 (61) obj. 96200 iterations 0
# Cbc0038I Pass  27: suminf.    0.04146 (81) obj. 97170 iterations 41
# Cbc0038I Pass  28: suminf.    0.03684 (77) obj. 97170 iterations 4
# Cbc0038I Pass  29: suminf.    0.03684 (77) obj. 97170 iterations 0
# Cbc0038I Pass  30: suminf.    0.03897 (95) obj. 101130 iterations 54
# Cbc0038I Rounding solution of 41910 is better than previous of 1e+50
#
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 12 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 408 rows 228 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of 37719
# Cbc0038I Pass  30: suminf.    0.03536 (7) obj. 37719 iterations 9
# Cbc0038I Pass  31: suminf.    0.00104 (3) obj. 37719 iterations 13
# Cbc0038I Pass  32: suminf.    0.00104 (3) obj. 37719 iterations 0
# Cbc0038I Pass  33: suminf.    1.33048 (58) obj. 37719 iterations 148
# Cbc0038I Pass  34: suminf.    0.02152 (46) obj. 37719 iterations 81
# Cbc0038I Pass  35: suminf.    0.01902 (42) obj. 37719 iterations 3
# Cbc0038I Pass  36: suminf.    0.01902 (42) obj. 37719 iterations 0
# Cbc0038I Pass  37: suminf.    1.21877 (66) obj. 37719 iterations 136
# Cbc0038I Pass  38: suminf.    0.01715 (50) obj. 37719 iterations 97
# Cbc0038I Pass  39: suminf.    0.01715 (50) obj. 37719 iterations 0
# Cbc0038I Pass  40: suminf.    0.03372 (61) obj. 37719 iterations 69
# Cbc0038I Pass  41: suminf.    0.02316 (50) obj. 37719 iterations 15
# Cbc0038I Pass  42: suminf.    0.01983 (45) obj. 37719 iterations 6
# Cbc0038I Pass  43: suminf.    0.01777 (42) obj. 37719 iterations 3
# Cbc0038I Pass  44: suminf.    0.01777 (42) obj. 37719 iterations 0
# Cbc0038I Pass  45: suminf.    1.10809 (84) obj. 37719 iterations 141
# Cbc0038I Pass  46: suminf.    0.02137 (65) obj. 37719 iterations 107
# Cbc0038I Pass  47: suminf.    0.02137 (65) obj. 37719 iterations 0
# Cbc0038I Pass  48: suminf.    1.56036 (91) obj. 37719 iterations 110
# Cbc0038I Pass  49: suminf.    1.01231 (91) obj. 37719 iterations 13
# Cbc0038I Pass  50: suminf.    0.01957 (73) obj. 37719 iterations 140
# Cbc0038I Pass  51: suminf.    0.01957 (73) obj. 37719 iterations 0
# Cbc0038I Pass  52: suminf.    0.05061 (77) obj. 37719 iterations 105
# Cbc0038I Pass  53: suminf.    0.03102 (58) obj. 37719 iterations 23
# Cbc0038I Pass  54: suminf.    0.02770 (55) obj. 37719 iterations 6
# Cbc0038I Pass  55: suminf.    0.02660 (53) obj. 37719 iterations 3
# Cbc0038I Pass  56: suminf.    0.02432 (53) obj. 37719 iterations 6
# Cbc0038I Pass  57: suminf.    0.02432 (53) obj. 37719 iterations 0
# Cbc0038I Pass  58: suminf.    0.25864 (83) obj. 37719 iterations 105
# Cbc0038I Pass  59: suminf.    0.02185 (74) obj. 37719 iterations 42
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 7 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 396 rows 224 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I After 0.10 seconds - Feasibility pump exiting with objective of 41910 - took 0.07 seconds
# Cbc0012I Integer solution of 41880 found by feasibility pump after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0012I Integer solution of 35770 found by DiveCoefficient after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 311 rows 141 columns - 2 fixed gives 309, 139 - still too large
# Cbc0038I Full problem 420 rows 250 columns, reduced to 309 rows 139 columns - too large
# Cbc0012I Integer solution of 2760 found by DiveCoefficient after 2758 iterations and 0 nodes (0.56 seconds)
# Cbc0031I 67 added rows had average density of 9.0298507
# Cbc0013I At root node, 67 cuts changed objective from 0 to 1355.7368 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 415 row cuts average 2.7 elements, 0 column cuts (13 active)  in 0.080 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 992 row cuts average 28.2 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 62 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 235 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 2760 best solution, best possible 1355.7368 (0.57 seconds)
# Cbc0012I Integer solution of 2580 found by DiveCoefficient after 2871 iterations and 3 nodes (0.63 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 239 rows 69 columns - 4 fixed gives 235, 65 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 234 rows 64 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 231 rows 61 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 241 rows 71 columns - 8 fixed gives 233, 63 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 228 rows 58 columns
# Cbc0012I Integer solution of 2520 found by DiveCoefficient after 15714 iterations and 337 nodes (2.79 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 239 rows 69 columns - 6 fixed gives 233, 63 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 228 rows 58 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 239 rows 69 columns - 7 fixed gives 232, 62 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 225 rows 55 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 240 rows 70 columns - 5 fixed gives 235, 65 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 233 rows 63 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 240 rows 70 columns - 1 fixed gives 239, 69 - still too large
# Cbc0038I Full problem 420 rows 250 columns, reduced to 239 rows 69 columns - too large
# Cbc0010I After 1000 nodes, 7 on tree, 2520 best solution, best possible 1355.7368 (6.19 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 233 rows 63 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 240 rows 70 columns - 4 fixed gives 236, 66 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 236 rows 66 columns
# Cbc0038I Full problem 420 rows 250 columns, reduced to 239 rows 69 columns - 3 fixed gives 236, 66 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 234 rows 64 columns
# Cbc0010I After 2000 nodes, 9 on tree, 2520 best solution, best possible 1418.696 (10.60 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 241 rows 71 columns - 6 fixed gives 235, 65 - ok now
# Cbc0038I Full problem 420 rows 250 columns, reduced to 233 rows 63 columns
# Cbc0010I After 3000 nodes, 7 on tree, 2520 best solution, best possible 1418.7054 (14.52 seconds)
# Cbc0001I Search completed - best objective 2520, took 135272 iterations and 3764 nodes (16.83 seconds)
# Cbc0032I Strong branching done 8392 times (91053 iterations), fathomed 264 nodes and fixed 1754 variables
# Cbc0035I Maximum depth 22, 2997 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 1355.74
# Probing was tried 8338 times and created 34768 cuts of which 13 were active after adding rounds of cuts (1.423 seconds)
# Gomory was tried 8295 times and created 16635 cuts of which 0 were active after adding rounds of cuts (1.186 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# MixedIntegerRounding2 was tried 100 times and created 62 cuts of which 0 were active after adding rounds of cuts (0.033 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# TwoMirCuts was tried 8295 times and created 1256 cuts of which 0 were active after adding rounds of cuts (0.738 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2520.00000000
# Enumerated nodes:               3764
# Total iterations:               135272
# Time (CPU seconds):             15.02
# Time (Wallclock seconds):       16.84
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       15.02   (Wallclock seconds):       16.84
#
# Valor ótimo da solução: 2520.0
# Tempos de pouso: 82.0, 90.0, 201.0, 270.0, 98.0, 122.0, 130.0, 114.0, 106.0, 280.0, 295.0, 146.0, 138.0, 291.0, 186.0, 154.0, 170.0, 178.0, 162.0, 357.0
# Tempo de execução do Solver: 16.87 segundos
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9fc4d7f94ebe43d99705c16407b77dec-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/9fc4d7f94ebe43d99705c16407b77dec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1225 COLUMNS
# At line 5186 RHS
# At line 6407 BOUNDS
# At line 6828 ENDATA
# Problem MODEL has 1220 rows, 440 columns and 3160 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0004I processed model has 420 rows, 250 columns (190 integer (190 of which binary)) and 1274 elements
# Cbc0038I Initial state - 49 integers unsatisfied sum - 3.47853
# Cbc0038I Pass   1: suminf.    0.00009 (1) obj. 18560 iterations 104
# Cbc0038I Pass   2: suminf.    0.00009 (1) obj. 18560 iterations 0
# Cbc0038I Pass   3: suminf.    0.02866 (51) obj. 62019.4 iterations 111
# Cbc0038I Pass   4: suminf.    0.02312 (46) obj. 61657.4 iterations 7
# Cbc0038I Pass   5: suminf.    0.02312 (46) obj. 61657.4 iterations 0
# Cbc0038I Pass   6: suminf.    0.03451 (63) obj. 80391.1 iterations 57
# Cbc0038I Pass   7: suminf.    0.03222 (61) obj. 80391.1 iterations 2
# Cbc0038I Pass   8: suminf.    0.03222 (61) obj. 80391.1 iterations 0
# Cbc0038I Pass   9: suminf.    0.04153 (69) obj. 83945.4 iterations 48
# Cbc0038I Pass  10: suminf.    0.03502 (63) obj. 77842.7 iterations 10
# Cbc0038I Pass  11: suminf.    0.03502 (63) obj. 77842.7 iterations 0
# Cbc0038I Pass  12: suminf.    0.03801 (68) obj. 82805.6 iterations 45
# Cbc0038I Pass  13: suminf.    0.03548 (66) obj. 76944.1 iterations 4
# Cbc0038I Pass  14: suminf.    0.03548 (66) obj. 76944.1 iterations 0
# Cbc0038I Pass  15: suminf.    0.03964 (68) obj. 85137.5 iterations 40
# Cbc0038I Pass  16: suminf.    0.03390 (63) obj. 77784.9 iterations 5
# Cbc0038I Pass  17: suminf.    0.03390 (63) obj. 77784.9 iterations 0
# Cbc0038I Pass  18: suminf.    0.04608 (71) obj. 97482.4 iterations 67
# Cbc0038I Pass  19: suminf.    0.03330 (61) obj. 59322.1 iterations 11
# Cbc0038I Pass  20: suminf.    0.03330 (61) obj. 59322.1 iterations 0
# Cbc0038I Pass  21: suminf.    0.03694 (69) obj. 59297.4 iterations 39
# Cbc0038I Pass  22: suminf.    0.02976 (63) obj. 59297.4 iterations 6
# Cbc0038I Pass  23: suminf.    0.02976 (63) obj. 59297.4 iterations 0
# Cbc0038I Pass  24: suminf.    0.02719 (70) obj. 68660.3 iterations 54
# Cbc0038I Pass  25: suminf.    0.02719 (70) obj. 68660.3 iterations 0
# Cbc0038I Pass  26: suminf.    0.02719 (70) obj. 68660.3 iterations 0
# Cbc0038I Pass  27: suminf.    0.03736 (99) obj. 73513.2 iterations 54
# Cbc0038I Pass  28: suminf.    0.03736 (99) obj. 73513.2 iterations 0
# Cbc0038I Pass  29: suminf.    0.03736 (99) obj. 73513.2 iterations 0
# Cbc0038I Pass  30: suminf.    0.04519 (101) obj. 64405.7 iterations 64
# Cbc0038I Rounding solution of 18560 is better than previous of 1e+50
#
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 10 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 408 rows 229 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of 16704
# Cbc0038I Pass  30: suminf.    0.00974 (6) obj. 16704 iterations 9
# Cbc0038I Pass  31: suminf.    0.00033 (3) obj. 16704 iterations 9
# Cbc0038I Pass  32: suminf.    0.00033 (3) obj. 16704 iterations 0
# Cbc0038I Pass  33: suminf.    1.50815 (52) obj. 16704 iterations 119
# Cbc0038I Pass  34: suminf.    0.02271 (35) obj. 16704 iterations 81
# Cbc0038I Pass  35: suminf.    0.00929 (22) obj. 16704 iterations 17
# Cbc0038I Pass  36: suminf.    0.00802 (20) obj. 16704 iterations 4
# Cbc0038I Pass  37: suminf.    0.00802 (20) obj. 16704 iterations 0
# Cbc0038I Pass  38: suminf.    1.42887 (58) obj. 16704 iterations 108
# Cbc0038I Pass  39: suminf.    0.86207 (55) obj. 16704 iterations 17
# Cbc0038I Pass  40: suminf.    0.02827 (42) obj. 16704 iterations 57
# Cbc0038I Pass  41: suminf.    0.01722 (36) obj. 16704 iterations 15
# Cbc0038I Pass  42: suminf.    0.01722 (36) obj. 16704 iterations 0
# Cbc0038I Pass  43: suminf.    0.69344 (70) obj. 16704 iterations 79
# Cbc0038I Pass  44: suminf.    0.03056 (55) obj. 16704 iterations 64
# Cbc0038I Pass  45: suminf.    0.01395 (50) obj. 16704 iterations 25
# Cbc0038I Pass  46: suminf.    0.00981 (51) obj. 16704 iterations 9
# Cbc0038I Pass  47: suminf.    0.00831 (50) obj. 16704 iterations 1
# Cbc0038I Pass  48: suminf.    0.00831 (50) obj. 16704 iterations 0
# Cbc0038I Pass  49: suminf.    1.38790 (70) obj. 16704 iterations 180
# Cbc0038I Pass  50: suminf.    0.83178 (68) obj. 16704 iterations 14
# Cbc0038I Pass  51: suminf.    0.03689 (58) obj. 16704 iterations 47
# Cbc0038I Pass  52: suminf.    0.00977 (46) obj. 16704 iterations 98
# Cbc0038I Pass  53: suminf.    0.00829 (45) obj. 16704 iterations 6
# Cbc0038I Pass  54: suminf.    0.00829 (45) obj. 16704 iterations 0
# Cbc0038I Pass  55: suminf.    0.95410 (74) obj. 16704 iterations 153
# Cbc0038I Pass  56: suminf.    0.64576 (73) obj. 16704 iterations 2
# Cbc0038I Pass  57: suminf.    0.01293 (53) obj. 16704 iterations 80
# Cbc0038I Pass  58: suminf.    0.00986 (50) obj. 16704 iterations 10
# Cbc0038I Pass  59: suminf.    0.00986 (50) obj. 16704 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 41 integers at bound fixed and 2 continuous
# Cbc0038I Full problem 420 rows 250 columns, reduced to 378 rows 207 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of 18560 - took 0.06 seconds
# Cbc0012I Integer solution of 18520 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0012I Integer solution of 17630 found by DiveCoefficient after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 279 rows 109 columns - 1 fixed gives 278, 108 - still too large
# Cbc0038I Full problem 420 rows 250 columns, reduced to 278 rows 108 columns - too large
# Cbc0012I Integer solution of 6380 found by DiveCoefficient after 3284 iterations and 0 nodes (0.60 seconds)
# Cbc0031I 53 added rows had average density of 25
# Cbc0013I At root node, 53 cuts changed objective from 0 to 1165.648 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 380 row cuts average 2.6 elements, 0 column cuts (2 active)  in 0.099 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 921 row cuts average 44.5 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 47 row cuts average 2.1 elements, 0 column cuts (0 active)  in 0.038 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 181 row cuts average 13.7 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 6380 best solution, best possible 1165.648 (0.62 seconds)
# Cbc0012I Integer solution of 6060 found by DiveCoefficient after 3424 iterations and 3 nodes (0.72 seconds)
# Cbc0016I Integer solution of 5480 found by strong branching after 4566 iterations and 39 nodes (1.22 seconds)
# Cbc0016I Integer solution of 4900 found by strong branching after 4570 iterations and 39 nodes (1.22 seconds)
# Cbc0016I Integer solution of 4320 found by strong branching after 4572 iterations and 39 nodes (1.22 seconds)
# Cbc0016I Integer solution of 3160 found by strong branching after 4581 iterations and 39 nodes (1.23 seconds)
# Cbc0038I Full problem 420 rows 250 columns, reduced to 240 rows 70 columns - 1 fixed gives 239, 69 - still too large
# Cbc0038I Full problem 420 rows 250 columns, reduced to 233 rows 63 columns
# ...
# Cgl0004I processed model has 210 rows, 151 columns (22 integer (22 of which binary)) and 579 elements
# Cbc0038I Initial state - 2 integers unsatisfied sum - 0.834688
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 1660 iterations 64
# Cbc0038I Solution found of 1660
# Cbc0038I Relaxing continuous gives 1660
# Cbc0038I Before mini branch and bound, 20 integers at bound fixed and 43 continuous
# Cbc0038I Full problem 210 rows 151 columns, reduced to 87 rows 66 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Freeing continuous variables gives a solution of 1660
# Cbc0038I Round again with cutoff of 1517.89
# Cbc0038I Pass   2: suminf.    0.00003 (1) obj. 1517.89 iterations 1
# Cbc0038I Pass   3: suminf.    0.00003 (1) obj. 1517.89 iterations 0
# Cbc0038I Pass   4: suminf.    0.00250 (3) obj. 1517.89 iterations 51
# Cbc0038I Pass   5: suminf.    0.17098 (3) obj. 1517.89 iterations 18
# Cbc0038I Pass   6: suminf.    0.00068 (3) obj. 1517.89 iterations 19
# Cbc0038I Pass   7: suminf.    0.00068 (3) obj. 1517.89 iterations 0
# Cbc0038I Pass   8: suminf.    0.14696 (8) obj. 1517.89 iterations 32
# Cbc0038I Pass   9: suminf.    0.00057 (3) obj. 1517.89 iterations 53
# Cbc0038I Pass  10: suminf.    0.00057 (3) obj. 1517.89 iterations 0
# Cbc0038I Pass  11: suminf.    0.39917 (6) obj. 1517.89 iterations 68
# Cbc0038I Pass  12: suminf.    0.17093 (2) obj. 1517.89 iterations 56
# Cbc0038I Pass  13: suminf.    0.00054 (2) obj. 1517.89 iterations 16
# Cbc0038I Pass  14: suminf.    0.00054 (2) obj. 1517.89 iterations 0
# Cbc0038I Pass  15: suminf.    0.00065 (3) obj. 1517.89 iterations 56
# Cbc0038I Pass  16: suminf.    0.00065 (3) obj. 1517.89 iterations 0
# Cbc0038I Pass  17: suminf.    0.00065 (3) obj. 1517.89 iterations 0
# Cbc0038I Pass  18: suminf.    1.29702 (8) obj. 1517.89 iterations 67
# Cbc0038I Pass  19: suminf.    0.00014 (1) obj. 1517.89 iterations 68
# Cbc0038I Pass  20: suminf.    0.00014 (1) obj. 1517.89 iterations 0
# Cbc0038I Pass  21: suminf.    1.95985 (11) obj. 1517.89 iterations 86
# Cbc0038I Pass  22: suminf.    1.95985 (11) obj. 1517.89 iterations 0
# Cbc0038I Pass  23: suminf.    0.17249 (3) obj. 1517.89 iterations 78
# Cbc0038I Pass  24: suminf.    0.00042 (2) obj. 1517.89 iterations 25
# Cbc0038I Pass  25: suminf.    0.00042 (2) obj. 1517.89 iterations 0
# Cbc0038I Pass  26: suminf.    1.07146 (8) obj. 1517.89 iterations 88
# Cbc0038I Pass  27: suminf.    1.07146 (8) obj. 1517.89 iterations 0
# Cbc0038I Pass  28: suminf.    0.17257 (3) obj. 1517.89 iterations 54
# Cbc0038I Pass  29: suminf.    0.00069 (3) obj. 1517.89 iterations 13
# Cbc0038I Pass  30: suminf.    0.00069 (3) obj. 1517.89 iterations 0
# Cbc0038I Pass  31: suminf.    1.58536 (8) obj. 1517.89 iterations 71
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 13 continuous
# Cbc0038I Full problem 210 rows 151 columns, reduced to 190 rows 131 columns - 18 fixed gives 160, 109 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I After 0.06 seconds - Feasibility pump exiting with objective of 1660 - took 0.03 seconds
# Cbc0012I Integer solution of 1660 found by feasibility pump after 0 iterations and 0 nodes (0.06 seconds)
# Cbc0038I Full problem 210 rows 151 columns, reduced to 190 rows 129 columns - 1 fixed gives 190, 129 - still too large
# Cbc0012I Integer solution of 1550 found by DiveCoefficient after 6 iterations and 0 nodes (0.07 seconds)
# Cbc0031I 2 added rows had average density of 5.5
# Cbc0013I At root node, 2 cuts changed objective from 238.88889 to 250.00833 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 3 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 1550 best solution, best possible 250.00833 (0.07 seconds)
# Cbc0038I Full problem 210 rows 151 columns, reduced to 192 rows 133 columns - 5 fixed gives 189, 128 - still too large
# Cbc0038I Full problem 210 rows 151 columns, reduced to 191 rows 130 columns - 2 fixed gives 189, 128 - still too large
# Cbc0038I Full problem 210 rows 151 columns, reduced to 191 rows 131 columns - 2 fixed gives 190, 129 - still too large
# Cbc0001I Search completed - best objective 1550.000000004947, took 7631 iterations and 466 nodes (1.69 seconds)
# Cbc0032I Strong branching done 890 times (6064 iterations), fathomed 148 nodes and fixed 38 variables
# Cbc0035I Maximum depth 11, 199 variables fixed on reduced cost
# Cuts at root node changed objective from 238.889 to 250.008
# Probing was tried 831 times and created 748 cuts of which 0 were active after adding rounds of cuts (0.071 seconds)
# Gomory was tried 831 times and created 709 cuts of which 0 were active after adding rounds of cuts (0.079 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 831 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1550.00000000
# Enumerated nodes:               466
# Total iterations:               7631
# Time (CPU seconds):             1.55
# Time (Wallclock seconds):       1.71
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.57   (Wallclock seconds):       1.73
#
# Valor ótimo da solução: 1550.0
# Tempos de pouso: 0.0, 96.0, 296.0, 376.0, 456.0, 528.0, 624.0, 720.0, 920.0, 992.0, 1192.0, 1264.0, 1464.0, 1544.0, 1616.0, 1816.0, 1896.0, 1968.0, 2168.0, 2248.0, 2320.0, 2416.0, 2616.0, 2688.0, 2888.0, 2968.0, 3048.0, 3128.0, 3200.0, 3296.0, 3496.0, 3568.0, 3768.0, 3840.0, 3936.0, 4136.0, 4216.0, 4296.0, 4368.0, 4464.0, 4560.0, 4656.0, 4752.0, 4952.0
# Tempo de execução do Solver: 1.83 segundos
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/guilherme/miniconda3/lib/python3.12/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3916679fe293476a92cb022781211161-pulp.mps -sec 640 -timeMode elapsed -branch -printingOptions all -solution /tmp/3916679fe293476a92cb022781211161-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 7555 COLUMNS
# At line 32456 RHS
# At line 40007 BOUNDS
# At line 42558 ENDATA
# Problem MODEL has 7550 rows, 2600 columns and 19900 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 640
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.02 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 921 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 138 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 65 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2524 rows, 1357 columns (1207 integer (1207 of which binary)) and 8648 elements
# Cbc0038I Initial state - 623 integers unsatisfied sum - 163.523
# Cbc0038I Pass   1: suminf.    3.24195 (234) obj. 171871 iterations 1309
# Cbc0038I Pass   2: suminf.    1.06166 (192) obj. 175470 iterations 97
# Cbc0038I Pass   3: suminf.    0.43918 (163) obj. 178275 iterations 84
# Cbc0038I Pass   4: suminf.    0.13229 (149) obj. 179005 iterations 51
# Cbc0038I Pass   5: suminf.    0.06951 (137) obj. 179155 iterations 30
# Cbc0038I Pass   6: suminf.    0.05311 (123) obj. 179155 iterations 14
# Cbc0038I Pass   7: suminf.    0.05311 (123) obj. 179155 iterations 0
# Cbc0038I Pass   8: suminf.    2.52226 (355) obj. 212186 iterations 350
# Cbc0038I Pass   9: suminf.    1.34496 (339) obj. 210620 iterations 29
# Cbc0038I Pass  10: suminf.    0.17094 (298) obj. 208351 iterations 94
# Cbc0038I Pass  11: suminf.    0.14257 (282) obj. 207712 iterations 22
# Cbc0038I Pass  12: suminf.    0.11895 (256) obj. 205659 iterations 26
# Cbc0038I Pass  13: suminf.    0.11776 (255) obj. 205659 iterations 1
# Cbc0038I Pass  14: suminf.    0.11776 (255) obj. 205659 iterations 0
# Cbc0038I Pass  15: suminf.    0.39209 (415) obj. 211719 iterations 293
# Cbc0038I Pass  16: suminf.    0.37779 (413) obj. 211719 iterations 2
# Cbc0038I Pass  17: suminf.    0.18798 (403) obj. 211074 iterations 35
# Cbc0038I Pass  18: suminf.    0.15734 (385) obj. 211029 iterations 23
# Cbc0038I Pass  19: suminf.    0.15734 (385) obj. 211029 iterations 0
# Cbc0038I Pass  20: suminf.    1.05567 (477) obj. 209969 iterations 339
# Cbc0038I Pass  21: suminf.    0.94117 (475) obj. 209528 iterations 11
# Cbc0038I Pass  22: suminf.    0.26586 (458) obj. 208187 iterations 53
# Cbc0038I Pass  23: suminf.    0.23697 (446) obj. 209377 iterations 29
# Cbc0038I Pass  24: suminf.    0.21583 (430) obj. 209012 iterations 19
# Cbc0038I Pass  25: suminf.    0.20357 (420) obj. 209012 iterations 10
# Cbc0038I Pass  26: suminf.    0.18143 (401) obj. 208308 iterations 22
# Cbc0038I Pass  27: suminf.    0.17836 (398) obj. 208308 iterations 3
# Cbc0038I Pass  28: suminf.    0.17836 (398) obj. 208308 iterations 0
# Cbc0038I Pass  29: suminf.    0.94579 (493) obj. 209453 iterations 374
# Cbc0038I Pass  30: suminf.    0.80615 (482) obj. 211270 iterations 40
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 204 integers at bound fixed and 37 continuous
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 2316 rows 1112 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.67 seconds)
# Cbc0038I Full problem 2525 rows 1357 columns, reduced to 2525 rows 1357 columns - too large
# Cbc0038I After 1.06 seconds - Feasibility pump exiting - took 0.68 seconds
# Cbc0012I Integer solution of 3010 found by DiveCoefficient after 3123 iterations and 0 nodes (4.18 seconds)
# Cbc0031I 524 added rows had average density of 11.578244
# Cbc0013I At root node, 524 cuts changed objective from 0 to 1220.9055 in 70 passes
# Cbc0014I Cut generator 0 (Probing) - 2534 row cuts average 10.6 elements, 0 column cuts (386 active)  in 0.860 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 1269 row cuts average 27.3 elements, 0 column cuts (0 active)  in 0.096 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.100 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.007 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 359 row cuts average 2.0 elements, 0 column cuts (0 active)  in 0.242 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.333 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 1147 row cuts average 4.6 elements, 0 column cuts (0 active)  in 0.127 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, 3010 best solution, best possible 1220.9055 (4.60 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1351 rows 228 columns
# Cbc0012I Integer solution of 2995 found by DiveCoefficient after 3241 iterations and 2 nodes (5.50 seconds)
# Cbc0012I Integer solution of 2800 found by DiveCoefficient after 3321 iterations and 3 nodes (6.45 seconds)
# Cbc0012I Integer solution of 2375 found by DiveCoefficient after 3322 iterations and 4 nodes (6.67 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1235 rows 168 columns
# Cbc0004I Integer solution of 2230 found after 3919 iterations and 59 nodes (9.38 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1220 rows 172 columns
# Cbc0010I After 100 nodes, 34 on tree, 2230 best solution, best possible 1220.9055 (10.09 seconds)
# Cbc0004I Integer solution of 1950 found after 9109 iterations and 166 nodes (10.64 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1212 rows 164 columns
# Cbc0010I After 200 nodes, 21 on tree, 1950 best solution, best possible 1220.9055 (10.97 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1211 rows 164 columns
# Cbc0010I After 300 nodes, 17 on tree, 1950 best solution, best possible 1220.9055 (11.63 seconds)
# Cbc0038I Full problem 2524 rows 1357 columns, reduced to 1230 rows 181 columns
# Cbc0010I After 400 nodes, 12 on tree, 1950 best solution, best possible 1300.3521 (14.20 seconds)
# Cbc0010I After 500 nodes, 17 on tree, 1950 best solution, best possible 1300.3521 (15.64 seconds)
# Cbc0001I Search completed - best objective 1950.000000002837, took 24320 iterations and 552 nodes (16.88 seconds)
# Cbc0032I Strong branching done 1358 times (24472 iterations), fathomed 17 nodes and fixed 65 variables
# Cbc0035I Maximum depth 64, 876 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 1220.91
# Probing was tried 572 times and created 7671 cuts of which 386 were active after adding rounds of cuts (1.381 seconds)
# Gomory was tried 572 times and created 2062 cuts of which 0 were active after adding rounds of cuts (0.409 seconds)
# Knapsack was tried 70 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.100 seconds)
# Clique was tried 70 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.007 seconds)
# MixedIntegerRounding2 was tried 572 times and created 448 cuts of which 0 were active after adding rounds of cuts (0.939 seconds)
# FlowCover was tried 70 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.333 seconds)
# TwoMirCuts was tried 572 times and created 1240 cuts of which 0 were active after adding rounds of cuts (0.373 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ImplicationCuts was tried 96 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
#
# Result - Optimal solution found
#
# Objective value:                1950.00000000
# Enumerated nodes:               552
# Total iterations:               24320
# Time (CPU seconds):             14.70
# Time (Wallclock seconds):       16.93
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       14.73   (Wallclock seconds):       16.97
#
# Valor ótimo da solução: 1950.0
# Tempos de pouso: 82.0, 197.0, 152.0, 117.0, 261.0, 101.0, 229.0, 109.0, 133.0, 136.0, 149.0, 125.0, 325.0, 316.0, 258.0, 422.0, 341.0, 287.0, 160.0, 175.0, 619.0, 425.0, 333.0, 269.0, 392.0, 378.0, 428.0, 498.0, 516.0, 634.0, 688.0, 512.0, 524.0, 556.0, 407.0, 717.0, 564.0, 572.0, 654.0, 725.0, 740.0, 763.0, 401.0, 441.0, 456.0, 673.0, 527.0, 580.0, 471.0, 345.0
# Tempo de execução do Solver: 17.11 segundos

# %% [markdown]
# # 3. Resolvendo usando a Heurística (VNS)
