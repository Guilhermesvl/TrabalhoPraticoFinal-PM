# %% [markdown]
# # 1. Formulação do problema
#
#     Variáveis de Decisão:
#         ti​ - Tempo de pouso do avião i (variável contínua);
#         xij​ - Variável binária que vale 1 se o avião i pousar antes do avião j, 0 caso contrário;
#         ei - Adiantamento do tempo ideal de pouso para o avião i (ei ≥ 0);
#         di - Atraso do tempo ideal de pouso para o avião i (di ≥ 0).
#
#     Parâmetros:
#
#         Ri - tempo de sua detecção pelo radar;
#         Ei - tempo inicial de pouso;
#         Ti - tempo ideal para o pouso;
#         Li - tempo final que o avião i pode pousar;
#
#     Função Objetivo:
#
#         Minimizar a penalidade total de pousos fora do tempo ideal:
#
# ## **Minimizar ∑ (gi * ei + hi * di)**
#
# Onde:
#
#     gi​ e hi​ são as penalidades por pousar antes ou depois do tempo ideal, respectivamente.
#
#     S.a:
#
#         Restrições de Viabilidade:
#
#             Cada avião deve pousar dentro do seu intervalo permitido:
#
#                 Ei ​≤ ti ​≤ Li ​∀i
#
#         Restrições de Separação:
#             O intervalo entre os pousos deve ser suficiente para garantir segurança:
#
#                 tj ≥ ti + sij - M(1 - xij) ∀i,j, i≠j
#
#                 M representa um valor grande.
#
#         Variáveis Binárias:
#
#                 xij​ + xji ​= 1 ∀i, j, i≠j
#
#         Cálculo de adiantamento e atraso:
#                 ei ​≥ Ti ​− ti  ​∀i
#                 di ≥ ti − Ti  ∀i

# %% [markdown]
# # Resolvendo usando o solver GLPK

# %%
import time
from pulp import value, LpProblem, LpVariable, LpMinimize, lpSum, LpBinary, LpStatus, GLPK_CMD

def ler_entrada_do_arquivo(caminho_arquivo):
    with open(caminho_arquivo, 'r') as arquivo:
        linha_inicial = arquivo.readline().strip().split()
        qtdeDeAvioes = int(linha_inicial[0])

        tempos = []
        separacoes = []
        penalidades = []

        for _ in range(qtdeDeAvioes):
            linha_tempos = arquivo.readline().strip().split()
            while len(linha_tempos) < 6:
                linha_tempos.extend(arquivo.readline().strip().split())
            ri, ei, ti, li, gi, hi = map(float, linha_tempos[:6])
            tempos.append((ri, ei, ti, li, gi, hi))
            penalidades.append((gi, hi))

            linha_separacao = []
            #Para adequar arquivos .dat com erro na formatacao
            while len(linha_separacao) < qtdeDeAvioes:
                linha_separacao.extend(arquivo.readline().strip().split())
            separacoes.append(list(map(float, linha_separacao[:qtdeDeAvioes])))

        return qtdeDeAvioes, tempos, separacoes, penalidades


def solverSequenciamento(n, tempos, separacoes, penalidades, instance_name):
    E = [temp[0] for temp in tempos]
    T = [temp[1] for temp in tempos]
    L = [temp[2] for temp in tempos]
    g = [penalidade[0] for penalidade in penalidades]
    h = [penalidade[1] for penalidade in penalidades]

    modelo = LpProblem("SequenciamentoPousos", LpMinimize)

    #Variaveis de decisao 
    t = [LpVariable(f"t_{i}", lowBound=E[i], upBound=L[i], cat='Continuous') for i in range(n)]
    e = [LpVariable(f"e_{i}", lowBound=0, cat='Continuous') for i in range(n)]
    d = [LpVariable(f"d_{i}", lowBound=0, cat='Continuous') for i in range(n)]
    x = [[LpVariable(f"x_{i}_{j}", cat=LpBinary) if i != j else None for j in range(n)] for i in range(n)]

    #Funcao Objetivo
    modelo += lpSum(g[i] * e[i] + h[i] * d[i] for i in range(n)), "PenalidadeTotal"

    #Restricoes de separacao e sequenciamento
    M = max(L) + max(separacoes[i][j] for i in range(n) for j in range(n) if i != j)

    for i in range(n):
        for j in range(n):
            if i != j:
                modelo += t[j] >= t[i] + separacoes[i][j] - M * (1 - x[i][j]), f"Separacao_{i}_{j}"
                modelo += x[i][j] + x[j][i] == 1, f"Sequencia_{i}_{j}"

    #Calculo de adiantamento e atraso
    for i in range(n):
        modelo += e[i] >= T[i] - t[i], f"Adiantamento_{i}"
        modelo += d[i] >= t[i] - T[i], f"Atraso_{i}"

    #Resolver o modelo  
    inicioTempo = time.time()  
    modelo.solve(GLPK_CMD(msg=True, timeLimit=300)) #talvez o tempo esteja impedindo as respostas do 06/07/08.dat
    tempoExecucao = time.time() - inicioTempo

    #Escreve as respostas solicitadas no arquivo .txt
    with open("solucoesOtimas.txt", "a") as arquivo_resultado:
        arquivo_resultado.write(f"\nInstância: {instance_name}\n")
        if LpStatus[modelo.status] == "Optimal":
            temposPouso = [t[i].varValue for i in range(n)]
            valor_otimo = value(modelo.objective)
            arquivo_resultado.write(f"Valor ótimo da solução (Solver): {valor_otimo}\n")
            arquivo_resultado.write(f"Tempos de pouso: {', '.join(map(str, temposPouso))}\n")
            arquivo_resultado.write(f"Tempo de execução do Solver: {tempoExecucao:.2f} segundos\n")
        else:
            arquivo_resultado.write("Não encontrou solução ótima.\n")


def executarTodasAsInstancias():
    for i in range(1, 9):
        caminho_arquivo = f"problema_do_aviao/instances/0{i}.dat"
        qtdeDeAvioes, tempos, separacoes, penalidades = ler_entrada_do_arquivo(caminho_arquivo)
        solverSequenciamento(qtdeDeAvioes, tempos, separacoes, penalidades, f"0{i}.dat")

executarTodasAsInstancias()
# Out:
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/28889f41fb7f46adb9fc521933fb5fa4-pulp.lp -o /tmp/28889f41fb7f46adb9fc521933fb5fa4-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/28889f41fb7f46adb9fc521933fb5fa4-pulp.lp'...
# 200 rows, 120 columns, 490 non-zeros
# 90 integer variables, all of which are binary
# 309 lines were read
# GLPK Integer Optimizer 5.0
# 200 rows, 120 columns, 490 non-zeros
# 90 integer variables, all of which are binary
# Preprocessing...
# 84 constraint coefficient(s) were reduced
# 193 rows, 114 columns, 470 non-zeros
# 84 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.280e+02  ratio =  2.280e+02
# GM: min|aij| =  6.880e-01  max|aij| =  1.454e+00  ratio =  2.113e+00
# EQ: min|aij| =  4.844e-01  max|aij| =  1.000e+00  ratio =  2.064e+00
# 2N: min|aij| =  2.500e-01  max|aij| =  1.703e+00  ratio =  6.812e+00
# Constructing initial basis...
# Size of triangular part is 151
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 193 rows, 114 columns, 470 non-zeros
#       0: obj =   0.000000000e+00 inf =   1.822e+02 (44)
#      67: obj =   3.180000000e+03 inf =   0.000e+00 (0)
# *    84: obj =   0.000000000e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    84: mip =     not found yet >=              -inf        (1; 0)
# +   165: >>>>>   1.520000000e+03 >=   0.000000000e+00 100.0% (32; 3)
# +   336: >>>>>   1.180000000e+03 >=   6.500000000e+02  44.9% (54; 16)
# +   546: >>>>>   1.150000000e+03 >=   7.000000000e+02  39.1% (48; 50)
# +   551: >>>>>   1.090000000e+03 >=   7.100000000e+02  34.9% (44; 61)
# +   686: >>>>>   1.060000000e+03 >=   8.100000000e+02  23.6% (35; 88)
# +   910: mip =   1.060000000e+03 >=     tree is empty   0.0% (0; 249)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.4 Mb (426904 bytes)
# Writing MIP solution to '/tmp/28889f41fb7f46adb9fc521933fb5fa4-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c29d039968b4494e9e9ebfb15a2a6bb8-pulp.lp -o /tmp/c29d039968b4494e9e9ebfb15a2a6bb8-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/c29d039968b4494e9e9ebfb15a2a6bb8-pulp.lp'...
# 450 rows, 255 columns, 1110 non-zeros
# 210 integer variables, all of which are binary
# 685 lines were read
# GLPK Integer Optimizer 5.0
# 450 rows, 255 columns, 1110 non-zeros
# 210 integer variables, all of which are binary
# Preprocessing...
# 130 constraint coefficient(s) were reduced
# 338 rows, 175 columns, 806 non-zeros
# 130 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.300e+02  ratio =  2.300e+02
# GM: min|aij| =  6.589e-01  max|aij| =  1.518e+00  ratio =  2.303e+00
# EQ: min|aij| =  4.401e-01  max|aij| =  1.000e+00  ratio =  2.272e+00
# 2N: min|aij| =  4.531e-01  max|aij| =  1.516e+00  ratio =  3.345e+00
# Constructing initial basis...
# Size of triangular part is 273
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 338 rows, 175 columns, 806 non-zeros
#       0: obj =   0.000000000e+00 inf =   2.386e+02 (52)
#      69: obj =   3.480000000e+03 inf =   0.000e+00 (0)
# *    88: obj =   1.065814104e-13 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    88: mip =     not found yet >=              -inf        (1; 0)
# +   321: >>>>>   2.370000000e+03 >=   0.000000000e+00 100.0% (54; 8)
# +   413: >>>>>   2.120000000e+03 >=   2.800000000e+02  86.8% (66; 9)
# + 19245: >>>>>   2.000000000e+03 >=   1.650000000e+03  17.5% (1423; 1499)
# + 25813: >>>>>   1.870000000e+03 >=   1.870000000e+03 < 0.1% (626; 4169)
# + 25813: mip =   1.870000000e+03 >=     tree is empty   0.0% (0; 7349)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   3.8 secs
# Memory used: 4.1 Mb (4283529 bytes)
# Writing MIP solution to '/tmp/c29d039968b4494e9e9ebfb15a2a6bb8-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/b2a89e106230481cb7092144a1990c57-pulp.lp -o /tmp/b2a89e106230481cb7092144a1990c57-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/b2a89e106230481cb7092144a1990c57-pulp.lp'...
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# 1212 lines were read
# GLPK Integer Optimizer 5.0
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# Preprocessing...
# 224 constraint coefficient(s) were reduced
# 584 rows, 284 columns, 1392 non-zeros
# 224 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.860e+02  ratio =  2.860e+02
# GM: min|aij| =  5.251e-01  max|aij| =  1.904e+00  ratio =  3.626e+00
# EQ: min|aij| =  2.800e-01  max|aij| =  1.000e+00  ratio =  3.571e+00
# 2N: min|aij| =  2.500e-01  max|aij| =  1.688e+00  ratio =  6.750e+00
# Constructing initial basis...
# Size of triangular part is 472
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 584 rows, 284 columns, 1392 non-zeros
#       0: obj =   0.000000000e+00 inf =   3.148e+02 (70)
#      96: obj =   2.980000000e+03 inf =   0.000e+00 (0)
# *   112: obj =   0.000000000e+00 inf =   0.000e+00 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   112: mip =     not found yet >=              -inf        (1; 0)
# +1095953: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (234809; 8488)
# +  4026: >>>>>   2.600000000e+03 >=   9.000000000e+02  65.4% (914; 53)
# +  5373: >>>>>   2.340000000e+03 >=   1.010000000e+03  56.8% (852; 805)
# +  8101: >>>>>   2.130000000e+03 >=   1.190000000e+03  44.1% (1248; 1047)
# +  8119: >>>>>   2.020000000e+03 >=   1.190000000e+03  41.1% (1063; 1335)
# +1096768: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (234986; 8496)
# + 16887: >>>>>   1.950000000e+03 >=   1.490000000e+03  23.6% (1711; 2228)
# + 16895: >>>>>   1.840000000e+03 >=   1.490000000e+03  19.0% (1434; 2668)
# + 26449: >>>>>   1.730000000e+03 >=   1.730000000e+03 < 0.1% (660; 6147)
# + 26449: mip =   1.730000000e+03 >=     tree is empty   0.0% (0; 9517)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   8.2 secs
# Memory used: 4.4 Mb (4568068 bytes)
# Writing MIP solution to '/tmp/b2a89e106230481cb7092144a1990c57-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/e1d989104862403b8cf1633cd126886e-pulp.lp -o /tmp/e1d989104862403b8cf1633cd126886e-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/e1d989104862403b8cf1633cd126886e-pulp.lp'...
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# 1212 lines were read
# GLPK Integer Optimizer 5.0
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# Preprocessing...
# 260 constraint coefficient(s) were reduced
# 638 rows, 320 columns, 1536 non-zeros
# 260 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.320e+02  ratio =  2.320e+02
# GM: min|aij| =  6.834e-01  max|aij| =  1.463e+00  ratio =  2.141e+00
# EQ: min|aij| =  4.794e-01  max|aij| =  1.000e+00  ratio =  2.086e+00
# 2N: min|aij| =  2.500e-01  max|aij| =  1.766e+00  ratio =  7.062e+00
# Constructing initial basis...
# Size of triangular part is 508
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 638 rows, 320 columns, 1536 non-zeros
#       0: obj =   0.000000000e+00 inf =   3.946e+02 (92)
#     116: obj =   2.240000000e+03 inf =   0.000e+00 (0) 1
# *   133: obj =   0.000000000e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   133: mip =     not found yet >=              -inf        (1; 0)
# +  1018: >>>>>   1.854000000e+04 >=   4.600000000e+02  97.5% (173; 5)
# Time used: 7040.6 secs.  Memory used: 402.0 Mb.
# +  6031: >>>>>   5.770000000e+03 >=   6.300000000e+02  89.1% (1005; 63)
# +1097780: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (235189; 8505)
# +  6876: >>>>>   5.650000000e+03 >=   6.600000000e+02  88.3% (558; 1174)
# +  7259: >>>>>   5.370000000e+03 >=   6.600000000e+02  87.7% (613; 1207)
# +  7388: >>>>>   4.310000000e+03 >=   6.600000000e+02  84.7% (600; 1289)
# +1098870: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (235364; 8518)
# + 25766: mip =   4.310000000e+03 >=   1.080000000e+03  74.9% (3467; 2071)
# +1099755: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (235554; 8528)
# + 46208: mip =   4.310000000e+03 >=   1.150000000e+03  73.3% (6258; 2534)
# +1100551: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (235708; 8540)
# + 64869: mip =   4.310000000e+03 >=   1.220000000e+03  71.7% (8837; 2987)
# +1101441: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (235913; 8549)
# + 81155: mip =   4.310000000e+03 >=   1.290000000e+03  70.1% (11293; 3470)
# + 83224: >>>>>   4.110000000e+03 >=   1.310000000e+03  68.1% (11562; 3514)
# +1102107: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (236102; 8554)
# +101573: mip =   4.110000000e+03 >=   1.400000000e+03  65.9% (13264; 5305)
# +1103146: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (236321; 8561)
# +118312: mip =   4.110000000e+03 >=   1.440000000e+03  65.0% (15428; 5743)
# +1104011: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (236526; 8568)
# +133315: mip =   4.110000000e+03 >=   1.490000000e+03  63.7% (17584; 6198)
# +134167: >>>>>   4.070000000e+03 >=   1.500000000e+03  63.1% (17721; 6218)
# +1104747: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (236706; 8578)
# +148336: mip =   4.070000000e+03 >=   1.530000000e+03  62.4% (19491; 6987)
# +158175: >>>>>   4.050000000e+03 >=   1.560000000e+03  61.5% (20848; 7283)
# +1105774: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (236908; 8583)
# +170135: mip =   4.050000000e+03 >=   1.560000000e+03  61.5% (22229; 7971)
# +1106568: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (237070; 8592)
# +182391: mip =   4.050000000e+03 >=   1.600000000e+03  60.5% (24060; 8366)
# +1107683: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (237253; 8598)
# +189887: >>>>>   4.010000000e+03 >=   1.620000000e+03  59.6% (25178; 8609)
# Time used: 60.0 secs.  Memory used: 47.1 Mb.
# Time used: 7100.7 secs.  Memory used: 405.9 Mb.
# +1108534: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (237426; 8605)
# +200612: mip =   4.010000000e+03 >=   1.630000000e+03  59.4% (26319; 9608)
# +1109280: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (237605; 8611)
# +207098: >>>>>   3.810000000e+03 >=   1.650000000e+03  56.7% (27130; 9794)
# +217773: mip =   3.810000000e+03 >=   1.660000000e+03  56.4% (26377; 14374)
# +1110242: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (237811; 8615)
# +228816: mip =   3.810000000e+03 >=   1.670000000e+03  56.2% (27857; 14737)
# +1111141: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (238014; 8620)
# +238949: mip =   3.810000000e+03 >=   1.680000000e+03  55.9% (29196; 15091)
# +1112434: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (238288; 8623)
# +249615: mip =   3.810000000e+03 >=   1.700000000e+03  55.4% (30655; 15399)
# +1113345: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (238484; 8631)
# +258795: mip =   3.810000000e+03 >=   1.710000000e+03  55.1% (31954; 15731)
# +1114406: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (238680; 8640)
# +269243: mip =   3.810000000e+03 >=   1.730000000e+03  54.6% (33321; 16043)
# +1115277: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (238892; 8647)
# +277898: mip =   3.810000000e+03 >=   1.740000000e+03  54.3% (34565; 16375)
# +1116252: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (239101; 8656)
# +286303: mip =   3.810000000e+03 >=   1.750000000e+03  54.1% (35649; 16702)
# +1117124: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (239283; 8660)
# +295186: mip =   3.810000000e+03 >=   1.770000000e+03  53.5% (36926; 17021)
# +1118092: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (239496; 8664)
# +303741: mip =   3.810000000e+03 >=   1.790000000e+03  53.0% (38096; 17312)
# +1119263: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (239748; 8668)
# Time used: 120.0 secs.  Memory used: 74.4 Mb.
# Time used: 7160.7 secs.  Memory used: 410.8 Mb.
# +311899: mip =   3.810000000e+03 >=   1.800000000e+03  52.8% (39246; 17618)
# +1120175: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (239944; 8674)
# +318913: mip =   3.810000000e+03 >=   1.810000000e+03  52.5% (40204; 17916)
# +1121226: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (240135; 8684)
# +326868: mip =   3.810000000e+03 >=   1.830000000e+03  52.0% (41308; 18220)
# +1122147: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (240353; 8691)
# +334997: mip =   3.810000000e+03 >=   1.830000000e+03  52.0% (42352; 18511)
# +1123150: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (240555; 8701)
# +344010: mip =   3.810000000e+03 >=   1.850000000e+03  51.4% (43592; 18783)
# +1124095: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (240758; 8704)
# +352100: mip =   3.810000000e+03 >=   1.860000000e+03  51.2% (44616; 19039)
# +1124930: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (240933; 8709)
# +359073: mip =   3.810000000e+03 >=   1.860000000e+03  51.2% (45542; 19321)
# +1125921: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (241117; 8716)
# +367246: mip =   3.810000000e+03 >=   1.880000000e+03  50.7% (46640; 19598)
# +1126683: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (241332; 8720)
# +376317: mip =   3.810000000e+03 >=   1.890000000e+03  50.4% (47721; 19871)
# +1127588: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (241535; 8724)
# +383024: mip =   3.810000000e+03 >=   1.900000000e+03  50.1% (48575; 20139)
# +1128516: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (241725; 8728)
# +391190: mip =   3.810000000e+03 >=   1.910000000e+03  49.9% (49540; 20397)
# +1129516: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (241932; 8733)
# +399647: mip =   3.810000000e+03 >=   1.910000000e+03  49.9% (50503; 20649)
# +1130462: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (242138; 8738)
# Time used: 180.0 secs.  Memory used: 98.4 Mb.
# Time used: 7220.7 secs.  Memory used: 415.0 Mb.
# +406389: mip =   3.810000000e+03 >=   1.920000000e+03  49.6% (51432; 20896)
# +1131018: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (242323; 8741)
# +412966: mip =   3.810000000e+03 >=   1.920000000e+03  49.6% (52179; 21158)
# +1132034: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (242510; 8745)
# +418844: mip =   3.810000000e+03 >=   1.930000000e+03  49.3% (52917; 21383)
# +1132967: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (242700; 8747)
# +425832: mip =   3.810000000e+03 >=   1.940000000e+03  49.1% (53717; 21608)
# +1133855: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (242871; 8753)
# +432984: mip =   3.810000000e+03 >=   1.950000000e+03  48.8% (54550; 21836)
# +1134525: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (243041; 8757)
# +439318: mip =   3.810000000e+03 >=   1.950000000e+03  48.8% (55363; 22048)
# +1135304: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (243214; 8760)
# +445134: mip =   3.810000000e+03 >=   1.960000000e+03  48.6% (56115; 22295)
# +1136337: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (243419; 8765)
# +452992: mip =   3.810000000e+03 >=   1.960000000e+03  48.6% (56897; 22545)
# +1137360: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (243615; 8772)
# +460832: mip =   3.810000000e+03 >=   1.970000000e+03  48.3% (57883; 22798)
# +1138216: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (243849; 8775)
# +465954: mip =   3.810000000e+03 >=   1.970000000e+03  48.3% (58505; 23026)
# +1138757: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244013; 8779)
# +473222: mip =   3.810000000e+03 >=   1.980000000e+03  48.0% (59432; 23270)
# +1139542: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244201; 8782)
# +477969: mip =   3.810000000e+03 >=   1.980000000e+03  48.0% (60028; 23522)
# +1140456: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244406; 8786)
# Time used: 240.0 secs.  Memory used: 117.7 Mb.
# Time used: 7280.7 secs.  Memory used: 418.9 Mb.
# +485282: mip =   3.810000000e+03 >=   1.990000000e+03  47.8% (60831; 23763)
# +1141358: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244596; 8793)
# +491782: mip =   3.810000000e+03 >=   2.000000000e+03  47.5% (61750; 23998)
# +1142203: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244815; 8796)
# +495616: mip =   3.810000000e+03 >=   2.000000000e+03  47.5% (62269; 24135)
# +1142480: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244897; 8798)
# +499575: mip =   3.810000000e+03 >=   2.000000000e+03  47.5% (62723; 24288)
# +1142925: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (244996; 8800)
# +502193: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (63089; 24416)
# +1143239: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245079; 8802)
# +506323: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (63624; 24550)
# +1143594: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245174; 8803)
# +509884: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (64048; 24691)
# +1144195: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245282; 8805)
# +513849: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (64496; 24833)
# +1144677: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245393; 8808)
# +516415: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (64872; 24971)
# +1145131: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245479; 8812)
# +518668: mip =   3.810000000e+03 >=   2.010000000e+03  47.2% (65175; 25098)
# +1145762: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245611; 8814)
# +523056: mip =   3.810000000e+03 >=   2.020000000e+03  47.0% (65681; 25249)
# +1146139: mip =   2.419000000e+04 >=   1.055000000e+03  95.6% (245748; 8817)
# +526980: mip =   3.810000000e+03 >=   2.020000000e+03  47.0% (66142; 25418)
# +528676: mip =   3.810000000e+03 >=   2.020000000e+03  47.0% (66281; 25479)
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# Time used:   300.1 secs
# Memory used: 130.1 Mb (136464742 bytes)
# Writing MIP solution to '/tmp/e1d989104862403b8cf1633cd126886e-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/c150524a3768465185605b56c0d96f51-pulp.lp -o /tmp/c150524a3768465185605b56c0d96f51-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/c150524a3768465185605b56c0d96f51-pulp.lp'...
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# 1212 lines were read
# GLPK Integer Optimizer 5.0
# 800 rows, 440 columns, 1980 non-zeros
# 380 integer variables, all of which are binary
# Preprocessing...
# 250 constraint coefficient(s) were reduced
# 627 rows, 310 columns, 1504 non-zeros
# 250 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.840e+02  ratio =  2.840e+02
# GM: min|aij| =  5.795e-01  max|aij| =  1.726e+00  ratio =  2.978e+00
# EQ: min|aij| =  3.380e-01  max|aij| =  1.000e+00  ratio =  2.958e+00
# 2N: min|aij| =  2.500e-01  max|aij| =  1.578e+00  ratio =  6.312e+00
# Constructing initial basis...
# Size of triangular part is 502
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 627 rows, 310 columns, 1504 non-zeros
#       0: obj =   0.000000000e+00 inf =   3.421e+02 (83)
#     100: obj =   4.900000000e+03 inf =   1.110e-15 (0)
# *   132: obj =   0.000000000e+00 inf =   7.105e-15 (0) 1
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   132: mip =     not found yet >=              -inf        (1; 0)
# +1146740: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (245891; 8829)
# Time used: 7340.7 secs.  Memory used: 421.2 Mb.
# +  1478: >>>>>   1.308000000e+04 >=   5.400000000e+02  95.9% (309; 18)
# +  2582: >>>>>   9.350000000e+03 >=   6.200000000e+02  93.4% (536; 38)
# +  4500: >>>>>   8.980000000e+03 >=   8.000000000e+02  91.1% (911; 76)
# +  4665: >>>>>   8.330000000e+03 >=   8.000000000e+02  90.4% (945; 87)
# +1147650: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246084; 8842)
# + 18875: mip =   8.330000000e+03 >=   1.160000000e+03  86.1% (3515; 354)
# + 23652: >>>>>   6.600000000e+03 >=   1.210000000e+03  81.7% (4386; 449)
# +1148550: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246290; 8849)
# + 34738: mip =   6.600000000e+03 >=   1.350000000e+03  79.5% (6064; 1208)
# +1149091: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246417; 8855)
# + 45076: mip =   6.600000000e+03 >=   1.430000000e+03  78.3% (7888; 1395)
# +1149591: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246514; 8867)
# + 55576: mip =   6.600000000e+03 >=   1.490000000e+03  77.4% (9768; 1597)
# +1150142: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246649; 8875)
# + 65247: mip =   6.600000000e+03 >=   1.530000000e+03  76.8% (11304; 1838)
# +1150705: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246788; 8884)
# + 75212: >>>>>   5.380000000e+03 >=   1.570000000e+03  70.8% (12982; 2064)
# +1151296: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (246915; 8889)
# + 84780: mip =   5.380000000e+03 >=   1.590000000e+03  70.4% (13336; 4676)
# +1151752: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247034; 8891)
# + 94340: mip =   5.380000000e+03 >=   1.620000000e+03  69.9% (14951; 4898)
# +1152518: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247171; 8895)
# +105633: mip =   5.380000000e+03 >=   1.660000000e+03  69.1% (16876; 5162)
# +1153471: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247358; 8898)
# +117040: mip =   5.380000000e+03 >=   1.700000000e+03  68.4% (18656; 5442)
# +1154144: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247513; 8902)
# +128080: >>>>>   5.260000000e+03 >=   1.730000000e+03  67.1% (20352; 5698)
# Time used: 60.0 secs.  Memory used: 35.9 Mb.
# Time used: 7400.7 secs.  Memory used: 424.5 Mb.
# +1154764: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247652; 8907)
# +138887: mip =   5.260000000e+03 >=   1.750000000e+03  66.7% (21791; 6429)
# +1155378: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247785; 8914)
# +149193: mip =   5.260000000e+03 >=   1.780000000e+03  66.2% (23394; 6715)
# +1156094: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (247942; 8921)
# +158542: mip =   5.260000000e+03 >=   1.800000000e+03  65.8% (24873; 6991)
# +1156638: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248058; 8934)
# +168555: mip =   5.260000000e+03 >=   1.820000000e+03  65.4% (26378; 7225)
# +1157392: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248216; 8941)
# +178138: mip =   5.260000000e+03 >=   1.840000000e+03  65.0% (27924; 7475)
# +1158041: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248377; 8943)
# +186506: mip =   5.260000000e+03 >=   1.860000000e+03  64.6% (29317; 7713)
# +1158754: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248528; 8946)
# +196854: mip =   5.260000000e+03 >=   1.880000000e+03  64.3% (30877; 7948)
# +1159481: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248672; 8948)
# +205237: mip =   5.260000000e+03 >=   1.890000000e+03  64.1% (32216; 8167)
# +1160069: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248786; 8951)
# +212582: mip =   5.260000000e+03 >=   1.900000000e+03  63.9% (33325; 8323)
# +1160573: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (248903; 8954)
# +219955: mip =   5.260000000e+03 >=   1.920000000e+03  63.5% (34481; 8493)
# +1161151: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249033; 8956)
# +227482: mip =   5.260000000e+03 >=   1.930000000e+03  63.3% (35593; 8673)
# +1161479: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249150; 8958)
# +234435: mip =   5.260000000e+03 >=   1.940000000e+03  63.1% (36676; 8845)
# Time used: 120.0 secs.  Memory used: 66.3 Mb.
# Time used: 7460.8 secs.  Memory used: 427.1 Mb.
# +1161914: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249243; 8960)
# +241440: mip =   5.260000000e+03 >=   1.950000000e+03  62.9% (37779; 8982)
# +1162394: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249335; 8963)
# +246591: mip =   5.260000000e+03 >=   1.960000000e+03  62.7% (38560; 9118)
# +1163006: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249454; 8965)
# +251467: mip =   5.260000000e+03 >=   1.970000000e+03  62.5% (39290; 9245)
# +1163510: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249562; 8966)
# +257161: mip =   5.260000000e+03 >=   1.980000000e+03  62.4% (40196; 9394)
# +1163977: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249675; 8969)
# +263654: mip =   5.260000000e+03 >=   1.990000000e+03  62.2% (41333; 9566)
# +1164566: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249777; 8972)
# +269683: mip =   5.260000000e+03 >=   1.990000000e+03  62.2% (42155; 9726)
# +1165077: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (249883; 8975)
# +276383: mip =   5.260000000e+03 >=   2.000000000e+03  62.0% (43136; 9885)
# +1165688: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250001; 8977)
# +281432: mip =   5.260000000e+03 >=   2.000000000e+03  62.0% (43955; 10076)
# +1166451: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250148; 8979)
# +289556: mip =   5.260000000e+03 >=   2.010000000e+03  61.8% (45199; 10311)
# +1167210: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250295; 8983)
# +298951: mip =   5.260000000e+03 >=   2.030000000e+03  61.4% (46659; 10542)
# +1167998: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250456; 8987)
# +309446: mip =   5.260000000e+03 >=   2.040000000e+03  61.2% (48224; 10778)
# +1168909: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250620; 8990)
# +318521: mip =   5.260000000e+03 >=   2.050000000e+03  61.0% (49669; 10990)
# Time used: 180.0 secs.  Memory used: 91.5 Mb.
# Time used: 7520.8 secs.  Memory used: 429.7 Mb.
# +1169979: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250807; 8993)
# +327812: mip =   5.260000000e+03 >=   2.060000000e+03  60.8% (50949; 11226)
# +1170927: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (250981; 8996)
# +336678: mip =   5.260000000e+03 >=   2.070000000e+03  60.6% (52238; 11465)
# +1172062: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (251190; 9000)
# +346243: mip =   5.260000000e+03 >=   2.080000000e+03  60.5% (53674; 11686)
# +353444: >>>>>   5.170000000e+03 >=   2.090000000e+03  59.6% (54677; 11876)
# +1172981: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (251376; 9004)
# +361936: mip =   5.170000000e+03 >=   2.100000000e+03  59.4% (55178; 13332)
# +1173841: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (251547; 9008)
# +369588: mip =   5.170000000e+03 >=   2.100000000e+03  59.4% (56398; 13550)
# +1174697: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (251731; 9012)
# +377714: mip =   5.170000000e+03 >=   2.110000000e+03  59.2% (57526; 13761)
# +1175490: mip =   2.419000000e+04 >=   1.060000000e+03  95.6% (251891; 9018)
# +385114: mip =   5.170000000e+03 >=   2.120000000e+03  59.0% (58586; 13972)
# +1176336: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252064; 9024)
# +391584: mip =   5.170000000e+03 >=   2.130000000e+03  58.8% (59530; 14159)
# +1176967: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252189; 9043)
# +395561: mip =   5.170000000e+03 >=   2.130000000e+03  58.8% (60115; 14272)
# +1177469: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252275; 9053)
# +399598: mip =   5.170000000e+03 >=   2.130000000e+03  58.8% (60727; 14398)
# +1178208: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252434; 9064)
# +401518: >>>>>   5.130000000e+03 >=   2.140000000e+03  58.3% (61009; 14446)
# +1178652: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252555; 9072)
# Time used: 240.0 secs.  Memory used: 114.1 Mb.
# Time used: 7580.8 secs.  Memory used: 433.0 Mb.
# +406479: mip =   5.130000000e+03 >=   2.140000000e+03  58.3% (61261; 15269)
# +1179551: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252702; 9078)
# +410963: mip =   5.130000000e+03 >=   2.140000000e+03  58.3% (61937; 15399)
# +1180036: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252811; 9085)
# +416088: mip =   5.130000000e+03 >=   2.150000000e+03  58.1% (62729; 15528)
# +1180630: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (252952; 9092)
# +420551: mip =   5.130000000e+03 >=   2.150000000e+03  58.1% (63359; 15672)
# +1181275: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253064; 9108)
# +426973: mip =   5.130000000e+03 >=   2.160000000e+03  57.9% (64253; 15844)
# +1182066: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253232; 9118)
# +433644: mip =   5.130000000e+03 >=   2.160000000e+03  57.9% (65267; 16030)
# +1182928: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253418; 9130)
# +440385: mip =   5.130000000e+03 >=   2.170000000e+03  57.7% (66211; 16204)
# +1183621: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253590; 9140)
# +446398: mip =   5.130000000e+03 >=   2.170000000e+03  57.7% (67019; 16379)
# +1184721: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253808; 9148)
# +452430: mip =   5.130000000e+03 >=   2.170000000e+03  57.7% (67900; 16547)
# +1185467: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (253994; 9157)
# +458846: mip =   5.130000000e+03 >=   2.180000000e+03  57.5% (68763; 16733)
# +1186209: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254141; 9174)
# +464931: mip =   5.130000000e+03 >=   2.190000000e+03  57.3% (69712; 16906)
# +1187247: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254350; 9182)
# +470767: mip =   5.130000000e+03 >=   2.190000000e+03  57.3% (70513; 17076)
# +475144: mip =   5.130000000e+03 >=   2.190000000e+03  57.3% (71190; 17199)
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# Time used:   300.1 secs
# Memory used: 134.9 Mb (141469518 bytes)
# Writing MIP solution to '/tmp/c150524a3768465185605b56c0d96f51-pulp.sol'...
# +1188021: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254521; 9192)
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/5ff1ed2bf1454524be199246aa7dbba0-pulp.lp -o /tmp/5ff1ed2bf1454524be199246aa7dbba0-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/5ff1ed2bf1454524be199246aa7dbba0-pulp.lp'...
# 1800 rows, 960 columns, 4470 non-zeros
# 870 integer variables, all of which are binary
# 2714 lines were read
# GLPK Integer Optimizer 5.0
# 1800 rows, 960 columns, 4470 non-zeros
# 870 integer variables, all of which are binary
# Preprocessing...
# PROBLEM HAS NO PRIMAL FEASIBLE SOLUTION
# Time used:   0.0 secs
# Memory used: 1.1 Mb (1177620 bytes)
# Writing MIP solution to '/tmp/5ff1ed2bf1454524be199246aa7dbba0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/0f0c5883d289452e8720299fb49c68a0-pulp.lp -o /tmp/0f0c5883d289452e8720299fb49c68a0-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/0f0c5883d289452e8720299fb49c68a0-pulp.lp'...
# Time used: 7640.8 secs.  Memory used: 436.5 Mb.
# 3872 rows, 2024 columns, 9636 non-zeros
# 1892 integer variables, all of which are binary
# 5824 lines were read
# GLPK Integer Optimizer 5.0
# 3872 rows, 2024 columns, 9636 non-zeros
# 1892 integer variables, all of which are binary
# Preprocessing...
# PROBLEM HAS NO PRIMAL FEASIBLE SOLUTION
# Time used:   0.0 secs
# Memory used: 2.4 Mb (2562132 bytes)
# Writing MIP solution to '/tmp/0f0c5883d289452e8720299fb49c68a0-pulp.sol'...
# GLPSOL--GLPK LP/MIP Solver 5.0
# Parameter(s) specified in the command line:
#  --cpxlp /tmp/2a5bc47206b24d3e90cf24db6576094d-pulp.lp -o /tmp/2a5bc47206b24d3e90cf24db6576094d-pulp.sol
#  --tmlim 300
# Reading problem data from '/tmp/2a5bc47206b24d3e90cf24db6576094d-pulp.lp'...
# 5000 rows, 2600 columns, 12450 non-zeros
# 2450 integer variables, all of which are binary
# 7520 lines were read
# GLPK Integer Optimizer 5.0
# 5000 rows, 2600 columns, 12450 non-zeros
# 2450 integer variables, all of which are binary
# Preprocessing...
# 1206 constraint coefficient(s) were reduced
# 3182 rows, 1356 columns, 7570 non-zeros
# 1206 integer variables, all of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  5.240e+02  ratio =  5.240e+02
# GM: min|aij| =  5.122e-01  max|aij| =  1.952e+00  ratio =  3.812e+00
# EQ: min|aij| =  2.641e-01  max|aij| =  1.000e+00  ratio =  3.787e+00
# 2N: min|aij| =  1.719e-01  max|aij| =  1.719e+00  ratio =  1.000e+01
# Constructing initial basis...
# Size of triangular part is 2579
# Solving LP relaxation...
# GLPK Simplex Optimizer 5.0
# 3182 rows, 1356 columns, 7570 non-zeros
#       0: obj =   0.000000000e+00 inf =   1.647e+03 (409)
#     448: obj =   3.708000000e+04 inf =   0.000e+00 (0) 4
# *   640: obj =   0.000000000e+00 inf =   1.776e-15 (0) 2
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   640: mip =     not found yet >=              -inf        (1; 0)
# +1188702: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254666; 9205)
# +   786: mip =     not found yet >=   0.000000000e+00        (88; 0)
# +1189438: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254825; 9212)
# +  1387: mip =     not found yet >=   3.000000000e+02        (210; 2)
# +1190254: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (254973; 9222)
# +  2251: mip =     not found yet >=   3.000000000e+02        (354; 6)
# +1190900: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255127; 9230)
# +  2790: mip =     not found yet >=   3.000000000e+02        (487; 9)
# +1191624: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255258; 9237)
# +  3371: mip =     not found yet >=   3.000000000e+02        (593; 12)
# +1192065: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255373; 9240)
# +  3839: mip =     not found yet >=   3.000000000e+02        (689; 13)
# +1192573: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255472; 9245)
# +  4204: mip =     not found yet >=   3.000000000e+02        (779; 15)
# +1193164: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255582; 9250)
# +  4625: mip =     not found yet >=   3.000000000e+02        (865; 18)
# +1193652: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255693; 9253)
# +  5078: mip =     not found yet >=   3.000000000e+02        (952; 21)
# +1194121: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255794; 9255)
# +  5470: mip =     not found yet >=   3.150000000e+02        (1045; 24)
# +1194542: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255883; 9258)
# +  6078: mip =     not found yet >=   3.150000000e+02        (1173; 26)
# Time used: 7700.8 secs.  Memory used: 439.0 Mb.
# Time used: 60.0 secs.  Memory used: 5.5 Mb.
# +1195032: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (255986; 9262)
# +  6560: mip =     not found yet >=   3.150000000e+02        (1270; 29)
# +1195608: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256087; 9268)
# +  7155: mip =     not found yet >=   3.150000000e+02        (1395; 33)
# +1196334: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256256; 9270)
# +  7819: mip =     not found yet >=   3.150000000e+02        (1527; 36)
# +  8405: mip =     not found yet >=   3.150000000e+02        (1653; 40)
# +1196733: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256390; 9272)
# +  9034: mip =     not found yet >=   3.150000000e+02        (1799; 42)
# +1197236: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256510; 9274)
# +  9413: mip =     not found yet >=   3.800000000e+02        (1925; 45)
# +1197772: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256621; 9277)
# +  9973: mip =     not found yet >=   4.350000000e+02        (2022; 49)
# +1198256: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256731; 9282)
# + 10585: mip =     not found yet >=   4.350000000e+02        (2149; 55)
# +1198912: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256866; 9285)
# + 11218: mip =     not found yet >=   4.350000000e+02        (2310; 58)
# +1199470: mip =   2.419000000e+04 >=   1.065000000e+03  95.6% (256985; 9289)
# +1200010: >>>>>   2.294000000e+04 >=   1.065000000e+03  95.4% (257106; 9290)
# + 11755: mip =     not found yet >=   4.800000000e+02        (2445; 62)
# +1200433: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256325; 10914)
# + 12417: mip =     not found yet >=   4.800000000e+02        (2581; 65)
# +1200884: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256432; 10919)
# + 12954: mip =     not found yet >=   4.800000000e+02        (2706; 66)
# +1201589: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256563; 10923)
# Time used: 7760.8 secs.  Memory used: 441.0 Mb.
# Time used: 120.1 secs.  Memory used: 7.2 Mb.
# + 13622: mip =     not found yet >=   4.800000000e+02        (2820; 68)
# +1202226: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256701; 10925)
# + 14163: mip =     not found yet >=   4.800000000e+02        (2908; 73)
# +1202865: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256829; 10928)
# + 14594: mip =     not found yet >=   4.800000000e+02        (3016; 75)
# +1203379: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (256942; 10934)
# + 15168: mip =     not found yet >=   4.800000000e+02        (3132; 77)
# +1203976: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (257048; 10938)
# + 15660: mip =     not found yet >=   4.800000000e+02        (3226; 79)
# +1204432: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (257138; 10940)
# + 15988: mip =     not found yet >=   4.800000000e+02        (3307; 81)
# +1204930: mip =   2.294000000e+04 >=   1.065000000e+03  95.4% (257233; 10942)
# + 16431: mip =     not found yet >=   4.800000000e+02        (3394; 84)
# +1205386: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257335; 10944)
# + 16878: mip =     not found yet >=   4.800000000e+02        (3486; 87)
# +1206033: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257445; 10949)
# + 17287: mip =     not found yet >=   4.800000000e+02        (3557; 90)
# +1206571: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257560; 10953)
# + 17757: mip =     not found yet >=   4.800000000e+02        (3643; 94)
# +1207072: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257649; 10959)
# + 18161: mip =     not found yet >=   4.800000000e+02        (3724; 98)
# +1207637: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257777; 10968)
# + 18634: mip =     not found yet >=   4.800000000e+02        (3832; 100)
# Time used: 7820.8 secs.  Memory used: 441.9 Mb.
# Time used: 180.1 secs.  Memory used: 8.4 Mb.
# +1208255: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (257905; 10976)
# + 19190: mip =     not found yet >=   4.800000000e+02        (3944; 102)
# +1208893: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258031; 10981)
# + 19769: mip =     not found yet >=   4.800000000e+02        (4059; 104)
# +1209492: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258165; 10983)
# + 20212: mip =     not found yet >=   4.800000000e+02        (4160; 107)
# +1209996: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258299; 10984)
# + 20794: mip =     not found yet >=   4.800000000e+02        (4271; 111)
# +1210543: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258408; 10986)
# + 21226: mip =     not found yet >=   4.900000000e+02        (4371; 114)
# +1211056: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258498; 10990)
# + 21881: mip =     not found yet >=   4.950000000e+02        (4503; 117)
# +1211618: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258583; 10996)
# + 22766: mip =     not found yet >=   4.950000000e+02        (4675; 119)
# +1212208: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258711; 10999)
# + 23431: mip =     not found yet >=   4.950000000e+02        (4800; 124)
# +1212715: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258810; 11001)
# + 24045: mip =     not found yet >=   4.950000000e+02        (4911; 130)
# +1213249: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (258909; 11005)
# + 24521: mip =     not found yet >=   4.950000000e+02        (5028; 134)
# + 25187: mip =     not found yet >=   4.950000000e+02        (5180; 136)
# +1213837: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259015; 11009)
# + 25571: mip =     not found yet >=   4.950000000e+02        (5264; 138)
# +1214174: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259092; 11011)
# Time used: 7880.9 secs.  Memory used: 443.9 Mb.
# Time used: 240.1 secs.  Memory used: 10.0 Mb.
# + 25990: mip =     not found yet >=   4.950000000e+02        (5352; 139)
# +1214525: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259172; 11013)
# + 26588: mip =     not found yet >=   4.950000000e+02        (5477; 142)
# +1214958: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259261; 11017)
# + 27251: mip =     not found yet >=   4.950000000e+02        (5614; 145)
# +1215393: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259356; 11020)
# + 27822: mip =     not found yet >=   4.950000000e+02        (5736; 149)
# +1215897: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259464; 11022)
# + 28473: mip =     not found yet >=   4.950000000e+02        (5877; 151)
# +1216316: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259548; 11023)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 79
#      76         qtdeDeAvioes, tempos, separacoes, penalidades = ler_entrada_do_arquivo(caminho_arquivo)
#      77         solverSequenciamento(qtdeDeAvioes, tempos, separacoes, penalidades, f"0{i}.dat")
# ---> 79 executarTodasAsInstancias()
#
# Cell In[54], line 77, in executarTodasAsInstancias()
#      75 caminho_arquivo = f"problema_do_aviao/instances/0{i}.dat"
#      76 qtdeDeAvioes, tempos, separacoes, penalidades = ler_entrada_do_arquivo(caminho_arquivo)
# ---> 77 solverSequenciamento(qtdeDeAvioes, tempos, separacoes, penalidades, f"0{i}.dat")
#
# Cell In[54], line 58, in solverSequenciamento(n, tempos, separacoes, penalidades, instance_name)
#      55     modelo += d[i] >= t[i] - T[i], f"Atraso_{i}"
#      57 inicio_tempo_solver = time.time()
# ---> 58 modelo.solve(GLPK_CMD(msg=True, timeLimit=300))
#      59 tempo_execucao_solver = time.time() - inicio_tempo_solver
#      61 with open("solucoesOtimas.txt", "a") as arquivo_resultado:
#
# File ~/miniconda3/lib/python3.12/site-packages/pulp/pulp.py:1867, in LpProblem.solve(self, solver, **kwargs)
#    1865 # time it
#    1866 self.startClock()
# -> 1867 status = solver.actualSolve(self, **kwargs)
#    1868 self.stopClock()
#    1869 self.restoreObjective(wasNone, dummyVar)
#
# File ~/miniconda3/lib/python3.12/site-packages/pulp/apis/glpk_api.py:105, in GLPK_CMD.actualSolve(self, lp)
#     103 else:
#     104     if os.name != "nt":
# --> 105         rc = os.spawnvp(os.P_WAIT, self.path, proc)
#     106     else:
#     107         rc = os.spawnv(os.P_WAIT, self.executable(self.path), proc)
#
# File <frozen os>:909, in spawnvp(mode, file, args)
#
# File <frozen os>:874, in _spawnvef(mode, file, args, env, func)
#
# KeyboardInterrupt:
# + 28800: mip =     not found yet >=   4.950000000e+02        (5996; 152)
# +1216805: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259648; 11025)
# + 29680: mip =     not found yet >=   4.950000000e+02        (6188; 156)
# +1217525: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259800; 11028)
# + 30285: mip =     not found yet >=   4.950000000e+02        (6326; 159)
# +1218395: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (259961; 11032)
# + 31197: mip =     not found yet >=   4.950000000e+02        (6513; 163)
# +1219176: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260125; 11034)
# + 32133: mip =     not found yet >=   4.950000000e+02        (6683; 169)
# +1220014: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260302; 11038)
# + 32919: mip =     not found yet >=   4.950000000e+02        (6885; 171)
# +1220671: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260430; 11041)
# + 33161: mip =     not found yet >=   5.100000000e+02        (6960; 173)
# +1221268: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260497; 11044)
# Time used: 7940.9 secs.  Memory used: 446.4 Mb.
# + 33534: mip =     not found yet >=   5.150000000e+02        (7050; 174)
# TIME LIMIT EXCEEDED; SEARCH TERMINATED
# Time used:   300.1 secs
# Memory used: 12.6 Mb (13172930 bytes)
# Writing MIP solution to '/tmp/2a5bc47206b24d3e90cf24db6576094d-pulp.sol'...
# +1222180: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260674; 11046)
# +1222951: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (260846; 11050)
# +1224098: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (261049; 11054)
# +1224858: mip =   2.294000000e+04 >=   1.070000000e+03  95.3% (261197; 11058)
# +1225613: mip =   2.294000000e+04 >=   1.075000000e+03  95.3% (261360; 11061)
# +1226510: mip =   2.294000000e+04 >=   1.075000000e+03  95.3% (261555; 11072)
# +1227513: mip =   2.294000000e+04 >=   1.075000000e+03  95.3% (261762; 11092)
# +1228432: mip =   2.294000000e+04 >=   1.075000000e+03  95.3% (261959; 11118)
